# %%
# This is the mergedRule dictionary.
# For each key-value pair:
# The key is the Pylint error code and the value(list) contains its corresponding Hyperstyle error codes
mergedRule = {
    "W0622": ["A001"], 
    "W0612": ["B007"], 
    "C0301": ["C001", "E501"], 
    "W0311": ["E111", "E113", "E999", "W0311"], 
    "C0103": ["E741", "N816"], 
    "E0601": ["F821"], 
    "C0325": ["WPS313","C0325"],
    "W1309": ["W1309"],
    "E0001": ["E0001"],
    "C0305": ["C0305"],
    "E0602": ["E0602"],
    "R1716": ["R1716"],
    "W0127": ["W0127"]
}

errorCodeExcluded = []
for pCode in mergedRule.keys():
    for hCode in mergedRule[pCode]:
        errorCodeExcluded.append(hCode)

# %%
# Read the PylintOutput file
pylintOutput = open("/Users/apple/Desktop/SummerResearch/Week1/pylintOutput.txt", "a")

# Data Preprocess Stage
pylintOutput.write("************")
pylintOutput.close()

# Store Each line of the Pylint Outcome
pylintOutput = open("/Users/apple/Desktop/SummerResearch/Week1/pylintOutput.txt")
lines = []
while True:
    line = pylintOutput.readline()
    lines.append(line)
    if ("" == line):
        break

# Categorize each student's warning message 
students = []
student = []
for line in lines:
    if line[0:12] == "************":
        students.append(student)
        student = []
    student.append(line)
students.pop(0)

# Process each student
# single_outcome = ['Student_ID', 'error code 1', 'error code 2', ...]
# outcome = [single_outcome1, single_outcome2, ...]

codeReference = set()
outcome = []
for student in students:
    single_outcome = []
    # Get the Student ID first
    indexOfStudentID = student[0].find("Module") + 17
    single_outcome.append(student[0][indexOfStudentID : ].strip('\n'))
    single_outcome.insert(0, int(student[0][indexOfStudentID + 1 : ].strip('\n')))
    
    # Get the error code of this student
    messages = student[1 : ]
    for message in messages:
        tokens = message.split() 
        # Pick the warning code
        for token in tokens:
            if (len(token) == 6) and (token[0].isalpha()) and (token[1 : 4].isdigit()) and token[-1] == ':':
                single_outcome.append(token[0 : 5])
                codeReference.add(message[message.find(token[0 : 5]):].strip('\n'))
    outcome.append(single_outcome)

# Sort elements based on students' ID
outcome.sort(key = lambda x:x[0])
for e in outcome:
    e.pop(0)
    
# Find and sort all unique warning code alphabetically 
allErrorCodeSet = set()
# studentInfo = ['Student_ID', 'error code 1', 'error code 2', ....]
for studentInfo in outcome:
    for i in range(1, len(studentInfo)):
        allErrorCodeSet.add(studentInfo[i])
        
allErrorCodes = list(allErrorCodeSet)
allErrorCodes.sort()

# Count the number of each warning code for each student
# processedStudent = [Student_ID, {"c0001": 2, "w0001": 3, ...}]
# processedStudents = [processedStudent1, processedStudent2, ...]

processedStudents = []
for single_outcome in outcome:
    processedStudent = [single_outcome[0]]
    frequencyMap = {}
    for i in range(1, len(single_outcome)):
        if single_outcome[i] not in frequencyMap:
            frequencyMap[single_outcome[i]] = 1
        else:
            frequencyMap[single_outcome[i]] += 1
    processedStudent.append(frequencyMap)
    processedStudents.append(processedStudent)
    
processedStudents
# Out:
# [['s01', {'C0303': 2, 'C0103': 1, 'C0114': 1, 'W0127': 2}],
#  ['s02', {'C0303': 1, 'C0103': 1, 'C0114': 1}],
#  ['s04', {'W0622': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s05', {'C0103': 1, 'C0114': 1}],
#  ['s06', {'W0622': 1, 'C0103': 1, 'C0114': 1}],
#  ['s16', {'C0103': 1, 'C0114': 1}],
#  ['s17', {'C0103': 1, 'C0114': 1, 'R1724': 1}],
#  ['s19', {'C0103': 1, 'C0114': 1}],
#  ['s22', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'W1309': 2, 'R1724': 1}],
#  ['s23', {'C0303': 1, 'C0103': 1, 'C0114': 1}],
#  ['s24', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s25', {'C0303': 2, 'C0325': 1, 'C0103': 1, 'C0114': 1, 'W0127': 1}],
#  ['s26', {'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s27', {'C0303': 2, 'C0103': 1, 'C0114': 1}],
#  ['s31', {'C0103': 1, 'C0114': 1}],
#  ['s32', {'C0103': 1, 'C0114': 1}],
#  ['s34', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s37', {'C0303': 1, 'C0103': 1, 'C0114': 1}],
#  ['s38', {'C0103': 1, 'C0114': 1, 'W1309': 2}],
#  ['s39', {'C0303': 2, 'C0103': 1, 'C0114': 1}],
#  ['s46', {'C0303': 1, 'C0305': 1, 'C0103': 1, 'C0114': 1}],
#  ['s48', {'C0103': 1, 'C0114': 1}],
#  ['s49', {'C0103': 2, 'C0114': 1}],
#  ['s52', {'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s53', {'E0001': 1}],
#  ['s54', {'C0103': 1, 'C0114': 1}],
#  ['s58', {'C0103': 1, 'C0114': 1, 'W1309': 2}],
#  ['s59', {'C0325': 1, 'C0103': 1, 'C0114': 1, 'R0801': 1}],
#  ['s100', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1, 'E0602': 2}],
#  ['s105', {'C0303': 2, 'C0103': 1, 'C0114': 1}],
#  ['s112', {'C0325': 1, 'C0103': 1, 'C0114': 1}],
#  ['s113', {'C0103': 1, 'C0114': 1}],
#  ['s114', {'C0103': 1, 'C0114': 1, 'W1309': 2}],
#  ['s115', {'C0303': 2, 'C0103': 1, 'C0114': 1, 'R1724': 1}],
#  ['s116', {'C0103': 1, 'C0114': 1}],
#  ['s118', {'C0301': 1, 'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s120', {'C0103': 1, 'C0114': 1}],
#  ['s121', {'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s123', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s124', {'C0325': 3, 'C0103': 1, 'C0114': 1}],
#  ['s126', {'C0103': 1, 'C0114': 1, 'E0602': 2}],
#  ['s127', {'C0301': 1, 'C0103': 1, 'C0114': 1}],
#  ['s129', {'W0311': 1, 'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s137', {'C0103': 1, 'C0114': 1, 'E0602': 1}]]

# %%
# Get reference to the meaning of each warning code
simpleCodeReference = []
allErrorCodesCpy = list(allErrorCodes)
for ref in codeReference:
    singleSimpleCodeReference = []
    singleSimpleCodeReference.append(ref[0:5])
    start = ref.rfind('(') + 1
    end = ref.rfind(')')
    if start == 0 or end == -1:
        singleSimpleCodeReference.append(ref[8:])
    else:
        singleSimpleCodeReference.append(ref[start : end])
    if singleSimpleCodeReference[0] in allErrorCodesCpy: 
        simpleCodeReference.append(singleSimpleCodeReference)
        allErrorCodesCpy.remove(singleSimpleCodeReference[0])

# Sort error codes
simpleCodeReference.sort(key = lambda x:x[0])
simpleCodeReference
# Out:
# [['C0103', 'invalid-name'],
#  ['C0114', 'missing-module-docstring'],
#  ['C0301', 'line-too-long'],
#  ['C0303', 'trailing-whitespace'],
#  ['C0305', 'trailing-newlines'],
#  ['C0325', 'superfluous-parens'],
#  ['E0001', 'syntax-error'],
#  ['E0602', 'undefined-variable'],
#  ['R0801', 'imilar lines in 2 files'],
#  ['R1716', 'chained-comparison'],
#  ['R1724', 'no-else-continue'],
#  ['W0127', 'self-assigning-variable'],
#  ['W0311', 'bad-indentation'],
#  ['W0622', 'redefined-builtin'],
#  ['W1309', 'f-string-without-interpolation']]

# %%
# Read the Hyperstyle JSON file
# import required module
from pathlib import Path
import json
 
# assign directory
directory = '/Users/apple/Desktop/SummerResearch/Week3/JSON_output'
 
processedStudentsHyperstyle = []
errorCodeSet = set()
errorCode = []

# iterate over files in that directory
files = Path(directory).glob('*')
for file in files:
    sFile = str(file)
    if sFile[-4:] == "json":
        f = open(file)
        student = json.load(f)
        processedStudent = []
        # Append the name of the solution
        processedStudent.append((int)(sFile[str(file).find("-s") + 2 : sFile.find(".")]))
        processedStudent.append(sFile[str(file).find("-s") + 1 : sFile.find(".")])
        
        # Append the code quality and text quality
        processedStudent.append(student["quality"]["code"])
        processedStudent.append(student["quality"]["text"][student["quality"]["text"].rfind(": ") + 2 : ])
        
        # Collect the student error
        frequencyMap = {}
        for issue in student["issues"]:
            if issue["code"] not in frequencyMap:
                frequencyMap[issue["code"]] = 1
            else:
                frequencyMap[issue["code"]] += 1
        processedStudent.append(frequencyMap)
        processedStudentsHyperstyle.append(processedStudent)
        
        # Collect error codes
        for issue in student["issues"]:
            if issue["code"] not in errorCodeSet:
                errorCodeSet.add(issue["code"])
                singleErrorCode = [issue["code"], issue["text"], issue["category"], issue["difficulty"]]
                errorCode.append(singleErrorCode)
                
# Sort the outcome
processedStudentsHyperstyle.sort(key = lambda x:x[0])
for e in processedStudentsHyperstyle:
    e.pop(0)
# print(*processedStudentsHyperstyle,sep='\n')
errorCode.sort(key = lambda x:x[0])
# print(*errorCode, sep = '\n')

print(*processedStudentsHyperstyle,sep='\n')
# Out:
# ['s01', 'BAD', 'BAD', {'E226': 1, 'W0127': 2, 'WPS434': 2}]
# ['s02', 'GOOD', 'GOOD', {'SC200': 4, 'E231': 1, 'E226': 1}]
# ['s04', 'BAD', 'BAD', {'A001': 1, 'E231': 1, 'E226': 1, 'R1716': 1, 'WPS222': 1, 'C001': 1}]
# ['s05', 'BAD', 'BAD', {'SC200': 3, 'E231': 1, 'E226': 1, 'E228': 3, 'E225': 1}]
# ['s06', 'BAD', 'BAD', {'E225': 7, 'A001': 1, 'E231': 1, 'WPS432': 1, 'E228': 3}]
# ['s16', 'GOOD', 'GOOD', {'SC200': 4, 'E211': 1, 'E231': 1, 'E226': 1}]
# ['s17', 'MODERATE', 'MODERATE', {'SC200': 4, 'E225': 2, 'E231': 1, 'E226': 1}]
# ['s19', 'MODERATE', 'MODERATE', {'E226': 1, 'E228': 3, 'E225': 1}]
# ['s22', 'BAD', 'BAD', {'W1309': 2, 'F541': 2, 'WPS237': 2, 'SC200': 5, 'WPS327': 1, 'E226': 1, 'WPS223': 1}]
# ['s23', 'GOOD', 'GOOD', {'E226': 1}]
# ['s24', 'BAD', 'BAD', {'E225': 1, 'E203': 1, 'R1716': 1, 'WPS313': 1, 'WPS222': 1, 'C001': 1}]
# ['s25', 'BAD', 'BAD', {'SC200': 5, 'E231': 1, 'E226': 1, 'WPS313': 2, 'E228': 2, 'E225': 1, 'W0127': 1, 'WPS434': 1}]
# ['s26', 'BAD', 'BAD', {'E231': 1, 'E226': 1, 'R1716': 1, 'E225': 2, 'E228': 3}]
# ['s27', 'BAD', 'BAD', {'E225': 4, 'SC200': 3, 'E231': 1, 'E226': 1, 'E228': 3}]
# ['s31', 'BAD', 'BAD', {'E741': 1, 'E226': 1, 'E225': 2, 'E228': 3}]
# ['s32', 'MODERATE', 'MODERATE', {'WPS327': 1, 'E203': 1, 'E228': 3}]
# ['s34', 'GOOD', 'GOOD', {'R1716': 1, 'E272': 1}]
# ['s37', 'BAD', 'BAD', {'E225': 7, 'SC200': 4, 'E231': 1, 'E226': 1, 'E228': 3}]
# ['s38', 'BAD', 'BAD', {'W1309': 2, 'F541': 2, 'WPS237': 2, 'E225': 4, 'E231': 1, 'E226': 1, 'E261': 3, 'E262': 3, 'E228': 3}]
# ['s39', 'MODERATE', 'MODERATE', {'E226': 1, 'E228': 3}]
# ['s46', 'BAD', 'BAD', {'E226': 1, 'E203': 1, 'C0305': 1}]
# ['s48', 'BAD', 'BAD', {'E226': 2, 'B007': 1, 'E231': 1, 'E228': 3, 'E225': 3}]
# ['s49', 'MODERATE', 'MODERATE', {'E211': 3, 'SC200': 2}]
# ['s52', 'MODERATE', 'MODERATE', {'E231': 1, 'E226': 1, 'R1716': 1, 'E228': 3}]
# ['s53', 'BAD', 'BAD', {'E0001': 1, 'E999': 1, 'E111': 1, 'E113': 1, 'E226': 1, 'E225': 4, 'E228': 3}]
# ['s54', 'MODERATE', 'MODERATE', {'SC200': 4, 'E231': 1, 'E226': 1, 'E261': 3, 'SC100': 1}]
# ['s58', 'BAD', 'BAD', {'W1309': 2, 'F541': 2, 'WPS237': 2, 'E225': 4, 'E231': 1, 'E226': 1, 'E261': 3, 'E262': 3, 'E228': 3}]
# ['s59', 'BAD', 'BAD', {'E265': 3, 'E231': 1, 'E226': 1, 'E228': 3, 'E225': 3, 'E261': 1, 'E262': 1, 'E211': 1}]
# ['s100', 'BAD', 'BAD', {'E231': 2, 'E226': 1, 'WPS440': 1, 'R1716': 1, 'E225': 5, 'WPS313': 1, 'E228': 3, 'E203': 1, 'WPS222': 1, 'C001': 1, 'E0602': 2, 'F821': 2, 'C0305': 1}]
# ['s105', 'MODERATE', 'MODERATE', {'SC200': 3, 'E231': 1, 'E226': 1, 'E225': 1}]
# ['s112', 'BAD', 'BAD', {'SC200': 3, 'E226': 6, 'E228': 3, 'E225': 3, 'WPS508': 1}]
# ['s113', 'MODERATE', 'MODERATE', {'SC200': 3, 'E231': 1, 'E226': 10}]
# ['s114', 'BAD', 'BAD', {'W1309': 2, 'F541': 2, 'WPS237': 2, 'E265': 1}]
# ['s115', 'BAD', 'BAD', {'E202': 2, 'E265': 2, 'E226': 1, 'SC200': 3, 'E225': 1, 'E228': 3}]
# ['s116', 'BAD', 'BAD', {'E211': 2, 'N816': 1, 'SC200': 4, 'E231': 1, 'E226': 1, 'E225': 1}]
# ['s118', 'BAD', 'BAD', {'E261': 5, 'E262': 5, 'R1716': 1, 'WPS508': 1}]
# ['s120', 'MODERATE', 'MODERATE', {'WPS407': 1, 'E226': 1, 'E228': 3, 'E225': 3}]
# ['s121', 'MODERATE', 'MODERATE', {'E203': 1, 'R1716': 1, 'WPS313': 1, 'WPS222': 1, 'C001': 1}]
# ['s123', 'MODERATE', 'MODERATE', {'E231': 1, 'E226': 1, 'R1716': 1, 'E228': 2, 'E225': 1}]
# ['s124', 'MODERATE', 'MODERATE', {'E231': 1, 'E226': 1, 'C0325': 3}]
# ['s126', 'BAD', 'BAD', {'E0602': 2, 'F821': 2, 'E231': 1, 'E226': 1, 'E228': 3, 'E225': 3}]
# ['s127', 'BAD', 'BAD', {'E265': 1, 'E262': 4, 'E226': 1, 'E501': 1}]
# ['s129', 'BAD', 'BAD', {'SC200': 3, 'E226': 1, 'W0311': 1, 'WPS440': 1, 'R1716': 1, 'E225': 1, 'WPS222': 1, 'C001': 1}]
# ['s137', 'BAD', 'BAD', {'E225': 6, 'SC200': 7, 'E0602': 1, 'F821': 1, 'E228': 3}]

# %%
# Get reference to the meaning of each warning code
simpleCodeReferenceHyper = []
for code in errorCode:
    if code[0] not in errorCodeExcluded:
        simpleCodeReferenceHyper.append(code)
print(*simpleCodeReferenceHyper, sep="\n")
# Out:
# ['E202', "whitespace before ')'", 'CODE_STYLE', 'EASY']
# ['E203', "whitespace before ':'", 'CODE_STYLE', 'EASY']
# ['E211', "whitespace before '('", 'CODE_STYLE', 'EASY']
# ['E225', 'missing whitespace around operator', 'CODE_STYLE', 'EASY']
# ['E226', 'missing whitespace around arithmetic operator', 'CODE_STYLE', 'EASY']
# ['E228', 'missing whitespace around modulo operator', 'CODE_STYLE', 'EASY']
# ['E231', "missing whitespace after ','", 'CODE_STYLE', 'EASY']
# ['E261', 'at least two spaces before inline comment', 'CODE_STYLE', 'EASY']
# ['E262', "inline comment should start with '# '", 'CODE_STYLE', 'EASY']
# ['E265', "block comment should start with '# '", 'CODE_STYLE', 'EASY']
# ['E272', 'multiple spaces before keyword', 'CODE_STYLE', 'EASY']
# ['F541', 'f-string is missing placeholders', 'BEST_PRACTICES', 'MEDIUM']
# ['SC100', "Possibly misspelt word: 'euqal'", 'INFO', 'EASY']
# ['SC200', "Possibly misspelt word: 'li3'", 'INFO', 'EASY']
# ['WPS222', 'Found a condition with too much logic: 5 > 4', 'COMPLEXITY', 'HARD']
# ['WPS223', 'Found too many `elif` branches: 4 > 3', 'COMPLEXITY', 'HARD']
# ['WPS237', 'Found a too complex `f` string', 'COMPLEXITY', 'HARD']
# ['WPS327', 'Found useless `continue` at the end of the loop', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS407', 'Found mutable module constant', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS432', "Found a magic number: 21. The use of unnamed magic numbers in code hides the developers' intent in choosing that number, increases opportunities for subtle errors and makes it more difficult for the program to be adapted and extended in the future. However, for small programs it can be allowed, but it is better to use constants instead of magic numbers.", 'INFO', 'EASY']
# ['WPS434', 'Found reassigning variable to itself: list4', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS440', 'Found block variables overlap: i', 'ERROR_PRONE', 'HARD']
# ['WPS508', 'Found incorrect `not` with compare usage', 'BEST_PRACTICES', 'MEDIUM']

# %%
# Merge students' error message from Pylint output and HyperStyle output based on their meanings
# mergedInfo[x] = [ID, Code Quality, Text Quality, {Pylint Error Count Map}, {Hyperstyle Error Count Map}, [Overlapped Hyperstyle ]]
mergedInfo = []
for i in range(len(processedStudents)):
    singleMergedInfo = [processedStudents[i][0], processedStudentsHyperstyle[i][1], processedStudentsHyperstyle[i][2]]
    # Merge common error codes
    pylintStudentError = dict(processedStudents[i][1])
    hyperStudentError = dict(processedStudentsHyperstyle[i][3])
    for pylintMapError in mergedRule.keys():
        if pylintMapError in pylintStudentError:
            hyperMapError = mergedRule[pylintMapError]
            additionalInfo = " ( Hyperstyle: "
            for oneHyperMapError in hyperMapError:
                if oneHyperMapError in hyperStudentError:
                    additionalInfo += str(oneHyperMapError) + ": " + str(hyperStudentError[oneHyperMapError]) + " "
                    hyperStudentError.pop(oneHyperMapError)
            if additionalInfo != " ( Hyperstyle: ":
                pylintStudentError[pylintMapError] = str(pylintStudentError[pylintMapError]) + additionalInfo + ")"
            else: 
                pylintStudentError[pylintMapError] = str(pylintStudentError[pylintMapError]) + " (-)"
    singleMergedInfo.append(pylintStudentError)
    singleMergedInfo.append(hyperStudentError)
    mergedInfo.append(singleMergedInfo)
mergedInfo
# Out:
# [['s01',
#   'BAD',
#   'BAD',
#   {'C0303': 2,
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'W0127': '2 ( Hyperstyle: W0127: 2 )'},
#   {'E226': 1, 'WPS434': 2}],
#  ['s02',
#   'GOOD',
#   'GOOD',
#   {'C0303': 1, 'C0103': '1 (-)', 'C0114': 1},
#   {'SC200': 4, 'E231': 1, 'E226': 1}],
#  ['s04',
#   'BAD',
#   'BAD',
#   {'W0622': '1 ( Hyperstyle: A001: 1 )',
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'R1716': '1 ( Hyperstyle: R1716: 1 )'},
#   {'E231': 1, 'E226': 1, 'WPS222': 1, 'C001': 1}],
#  ['s05',
#   'BAD',
#   'BAD',
#   {'C0103': '1 (-)', 'C0114': 1},
#   {'SC200': 3, 'E231': 1, 'E226': 1, 'E228': 3, 'E225': 1}],
#  ['s06',
#   'BAD',
#   'BAD',
#   {'W0622': '1 ( Hyperstyle: A001: 1 )', 'C0103': '1 (-)', 'C0114': 1},
#   {'E225': 7, 'E231': 1, 'WPS432': 1, 'E228': 3}],
#  ['s16',
#   'GOOD',
#   'GOOD',
#   {'C0103': '1 (-)', 'C0114': 1},
#   {'SC200': 4, 'E211': 1, 'E231': 1, 'E226': 1}],
#  ['s17',
#   'MODERATE',
#   'MODERATE',
#   {'C0103': '1 (-)', 'C0114': 1, 'R1724': 1},
#   {'SC200': 4, 'E225': 2, 'E231': 1, 'E226': 1}],
#  ['s19',
#   'MODERATE',
#   'MODERATE',
#   {'C0103': '1 (-)', 'C0114': 1},
#   {'E226': 1, 'E228': 3, 'E225': 1}],
#  ['s22',
#   'BAD',
#   'BAD',
#   {'C0303': 1,
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'W1309': '2 ( Hyperstyle: W1309: 2 )',
#    'R1724': 1},
#   {'F541': 2, 'WPS237': 2, 'SC200': 5, 'WPS327': 1, 'E226': 1, 'WPS223': 1}],
#  ['s23',
#   'GOOD',
#   'GOOD',
#   {'C0303': 1, 'C0103': '1 (-)', 'C0114': 1},
#   {'E226': 1}],
#  ['s24',
#   'BAD',
#   'BAD',
#   {'C0303': 1,
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'R1716': '1 ( Hyperstyle: R1716: 1 )'},
#   {'E225': 1, 'E203': 1, 'WPS313': 1, 'WPS222': 1, 'C001': 1}],
#  ['s25',
#   'BAD',
#   'BAD',
#   {'C0303': 2,
#    'C0325': '1 ( Hyperstyle: WPS313: 2 )',
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'W0127': '1 ( Hyperstyle: W0127: 1 )'},
#   {'SC200': 5, 'E231': 1, 'E226': 1, 'E228': 2, 'E225': 1, 'WPS434': 1}],
#  ['s26',
#   'BAD',
#   'BAD',
#   {'C0103': '1 (-)', 'C0114': 1, 'R1716': '1 ( Hyperstyle: R1716: 1 )'},
#   {'E231': 1, 'E226': 1, 'E225': 2, 'E228': 3}],
#  ['s27',
#   'BAD',
#   'BAD',
#   {'C0303': 2, 'C0103': '1 (-)', 'C0114': 1},
#   {'E225': 4, 'SC200': 3, 'E231': 1, 'E226': 1, 'E228': 3}],
#  ['s31',
#   'BAD',
#   'BAD',
#   {'C0103': '1 ( Hyperstyle: E741: 1 )', 'C0114': 1},
#   {'E226': 1, 'E225': 2, 'E228': 3}],
#  ['s32',
#   'MODERATE',
#   'MODERATE',
#   {'C0103': '1 (-)', 'C0114': 1},
#   {'WPS327': 1, 'E203': 1, 'E228': 3}],
#  ['s34',
#   'GOOD',
#   'GOOD',
#   {'C0303': 1,
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'R1716': '1 ( Hyperstyle: R1716: 1 )'},
#   {'E272': 1}],
#  ['s37',
#   'BAD',
#   'BAD',
#   {'C0303': 1, 'C0103': '1 (-)', 'C0114': 1},
#   {'E225': 7, 'SC200': 4, 'E231': 1, 'E226': 1, 'E228': 3}],
#  ['s38',
#   'BAD',
#   'BAD',
#   {'C0103': '1 (-)', 'C0114': 1, 'W1309': '2 ( Hyperstyle: W1309: 2 )'},
#   {'F541': 2,
#    'WPS237': 2,
#    'E225': 4,
#    'E231': 1,
#    'E226': 1,
#    'E261': 3,
#    'E262': 3,
#    'E228': 3}],
#  ['s39',
#   'MODERATE',
#   'MODERATE',
#   {'C0303': 2, 'C0103': '1 (-)', 'C0114': 1},
#   {'E226': 1, 'E228': 3}],
#  ['s46',
#   'BAD',
#   'BAD',
#   {'C0303': 1,
#    'C0305': '1 ( Hyperstyle: C0305: 1 )',
#    'C0103': '1 (-)',
#    'C0114': 1},
#   {'E226': 1, 'E203': 1}],
#  ['s48',
#   'BAD',
#   'BAD',
#   {'C0103': '1 (-)', 'C0114': 1},
#   {'E226': 2, 'B007': 1, 'E231': 1, 'E228': 3, 'E225': 3}],
#  ['s49',
#   'MODERATE',
#   'MODERATE',
#   {'C0103': '2 (-)', 'C0114': 1},
#   {'E211': 3, 'SC200': 2}],
#  ['s52',
#   'MODERATE',
#   'MODERATE',
#   {'C0103': '1 (-)', 'C0114': 1, 'R1716': '1 ( Hyperstyle: R1716: 1 )'},
#   {'E231': 1, 'E226': 1, 'E228': 3}],
#  ['s53',
#   'BAD',
#   'BAD',
#   {'E0001': '1 ( Hyperstyle: E0001: 1 )'},
#   {'E999': 1, 'E111': 1, 'E113': 1, 'E226': 1, 'E225': 4, 'E228': 3}],
#  ['s54',
#   'MODERATE',
#   'MODERATE',
#   {'C0103': '1 (-)', 'C0114': 1},
#   {'SC200': 4, 'E231': 1, 'E226': 1, 'E261': 3, 'SC100': 1}],
#  ['s58',
#   'BAD',
#   'BAD',
#   {'C0103': '1 (-)', 'C0114': 1, 'W1309': '2 ( Hyperstyle: W1309: 2 )'},
#   {'F541': 2,
#    'WPS237': 2,
#    'E225': 4,
#    'E231': 1,
#    'E226': 1,
#    'E261': 3,
#    'E262': 3,
#    'E228': 3}],
#  ['s59',
#   'BAD',
#   'BAD',
#   {'C0325': '1 (-)', 'C0103': '1 (-)', 'C0114': 1, 'R0801': 1},
#   {'E265': 3,
#    'E231': 1,
#    'E226': 1,
#    'E228': 3,
#    'E225': 3,
#    'E261': 1,
#    'E262': 1,
#    'E211': 1}],
#  ['s100',
#   'BAD',
#   'BAD',
#   {'C0303': 1,
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'R1716': '1 ( Hyperstyle: R1716: 1 )',
#    'E0602': '2 ( Hyperstyle: E0602: 2 )'},
#   {'E231': 2,
#    'E226': 1,
#    'WPS440': 1,
#    'E225': 5,
#    'WPS313': 1,
#    'E228': 3,
#    'E203': 1,
#    'WPS222': 1,
#    'C001': 1,
#    'F821': 2,
#    'C0305': 1}],
#  ['s105',
#   'MODERATE',
#   'MODERATE',
#   {'C0303': 2, 'C0103': '1 (-)', 'C0114': 1},
#   {'SC200': 3, 'E231': 1, 'E226': 1, 'E225': 1}],
#  ['s112',
#   'BAD',
#   'BAD',
#   {'C0325': '1 (-)', 'C0103': '1 (-)', 'C0114': 1},
#   {'SC200': 3, 'E226': 6, 'E228': 3, 'E225': 3, 'WPS508': 1}],
#  ['s113',
#   'MODERATE',
#   'MODERATE',
#   {'C0103': '1 (-)', 'C0114': 1},
#   {'SC200': 3, 'E231': 1, 'E226': 10}],
#  ['s114',
#   'BAD',
#   'BAD',
#   {'C0103': '1 (-)', 'C0114': 1, 'W1309': '2 ( Hyperstyle: W1309: 2 )'},
#   {'F541': 2, 'WPS237': 2, 'E265': 1}],
#  ['s115',
#   'BAD',
#   'BAD',
#   {'C0303': 2, 'C0103': '1 (-)', 'C0114': 1, 'R1724': 1},
#   {'E202': 2, 'E265': 2, 'E226': 1, 'SC200': 3, 'E225': 1, 'E228': 3}],
#  ['s116',
#   'BAD',
#   'BAD',
#   {'C0103': '1 ( Hyperstyle: N816: 1 )', 'C0114': 1},
#   {'E211': 2, 'SC200': 4, 'E231': 1, 'E226': 1, 'E225': 1}],
#  ['s118',
#   'BAD',
#   'BAD',
#   {'C0301': '1 (-)',
#    'C0303': 1,
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'R1716': '1 ( Hyperstyle: R1716: 1 )'},
#   {'E261': 5, 'E262': 5, 'WPS508': 1}],
#  ['s120',
#   'MODERATE',
#   'MODERATE',
#   {'C0103': '1 (-)', 'C0114': 1},
#   {'WPS407': 1, 'E226': 1, 'E228': 3, 'E225': 3}],
#  ['s121',
#   'MODERATE',
#   'MODERATE',
#   {'C0103': '1 (-)', 'C0114': 1, 'R1716': '1 ( Hyperstyle: R1716: 1 )'},
#   {'E203': 1, 'WPS313': 1, 'WPS222': 1, 'C001': 1}],
#  ['s123',
#   'MODERATE',
#   'MODERATE',
#   {'C0303': 1,
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'R1716': '1 ( Hyperstyle: R1716: 1 )'},
#   {'E231': 1, 'E226': 1, 'E228': 2, 'E225': 1}],
#  ['s124',
#   'MODERATE',
#   'MODERATE',
#   {'C0325': '3 ( Hyperstyle: C0325: 3 )', 'C0103': '1 (-)', 'C0114': 1},
#   {'E231': 1, 'E226': 1}],
#  ['s126',
#   'BAD',
#   'BAD',
#   {'C0103': '1 (-)', 'C0114': 1, 'E0602': '2 ( Hyperstyle: E0602: 2 )'},
#   {'F821': 2, 'E231': 1, 'E226': 1, 'E228': 3, 'E225': 3}],
#  ['s127',
#   'BAD',
#   'BAD',
#   {'C0301': '1 ( Hyperstyle: E501: 1 )', 'C0103': '1 (-)', 'C0114': 1},
#   {'E265': 1, 'E262': 4, 'E226': 1}],
#  ['s129',
#   'BAD',
#   'BAD',
#   {'W0311': '1 ( Hyperstyle: W0311: 1 )',
#    'C0303': 1,
#    'C0103': '1 (-)',
#    'C0114': 1,
#    'R1716': '1 ( Hyperstyle: R1716: 1 )'},
#   {'SC200': 3, 'E226': 1, 'WPS440': 1, 'E225': 1, 'WPS222': 1, 'C001': 1}],
#  ['s137',
#   'BAD',
#   'BAD',
#   {'C0103': '1 (-)', 'C0114': 1, 'E0602': '1 ( Hyperstyle: E0602: 1 )'},
#   {'E225': 6, 'SC200': 7, 'F821': 1, 'E228': 3}]]

# %%
# import package
import xlsxwriter 
from openpyxl import Workbook
from openpyxl.styles import Alignment
from openpyxl.styles import PatternFill
from openpyxl.styles import Font

# Create Workbook 
workbook = Workbook()

# Delete the empty worksheet
del workbook["Sheet"]

# Sheets Names
sName1 = "Comparision of Tools' Outcomes"

# Create Sheet
workbook.create_sheet(sName1)

# Choose worksheet
sheet = workbook[sName1]

# %%
# Create worksheet x-axis title
sheet["A1"] = "Student ID"
sheet.column_dimensions['A'].width = 30
sheet["A1"].alignment = Alignment(horizontal = 'center')
sheet["B1"] = "Code Quality"
sheet.column_dimensions['B'].width = 30
sheet["B1"].alignment = Alignment(horizontal = 'center')
sheet["C1"] = "Text Quality"
sheet.column_dimensions['C'].width = 30
sheet["C1"].alignment = Alignment(horizontal = 'center')

index = 0
for row in sheet.iter_rows(min_row = 1, min_col = 4, max_row = 1, max_col = len(simpleCodeReference) + 3):
    for cell in row:
        sheet.column_dimensions[xlsxwriter.utility.xl_col_to_name(cell.column - 1)].width = 40
        cell.value = simpleCodeReference[index][0]
        cell.alignment = Alignment(horizontal = 'center')
        cell.fill = PatternFill(start_color = "00FFFF00", end_color = "00FFFF00", fill_type = "solid")
        cell.font = Font(bold = True)
        index += 1
        
index = 0
for row in sheet.iter_rows(min_row = 1, min_col = len(simpleCodeReference) + 7, max_row = 1, max_col = len(simpleCodeReference) + len(simpleCodeReferenceHyper) + 6):
    for cell in row:
        sheet.column_dimensions[xlsxwriter.utility.xl_col_to_name(cell.column - 1)].width = 40
        cell.value = simpleCodeReferenceHyper[index][0]
        cell.alignment = Alignment(horizontal = 'center')
        cell.fill = PatternFill(start_color = "00FFFF00", end_color = "00FFFF00", fill_type = "solid")
        cell.font = Font(bold = True)
        index += 1

# %%
# Fill in the information of each student (Pylint)

# Define the level of numbers of errors (for visualizarion later)
maxError = 0
for processedStudent in processedStudents:
    if maxError < max(processedStudent[1].values()):
        maxError = max(processedStudent[1].values())

studentIndex = 0
for row in sheet.iter_rows(min_row = 2, min_col = 1, max_row = len(processedStudents) + 1, max_col = len(simpleCodeReference) + 3):
    flag = True
    errorCodeIndex = 0
    for cell in row:
        if flag:
            cell.value = processedStudents[studentIndex][0]
            cell.font = Font(bold = True)
            flag = False
        elif cell.column == 2:
            cell.value = mergedInfo[studentIndex][1]
            cell.font = Font(bold = True)
            if cell.value == "BAD":
                cell.fill = PatternFill(start_color = 'FF0000', end_color = 'FF0000', fill_type = "solid")
            elif cell.value == "MODERATE":
                cell.fill = PatternFill(start_color = 'FFFF00', end_color = 'FFFF00', fill_type = "solid")
            else:
                cell.fill = PatternFill(start_color = '00FF00', end_color = '00FF00', fill_type = "solid")
        elif cell.column == 3:
            cell.value = mergedInfo[studentIndex][2]
            cell.font = Font(bold = True)
        else:
            # Loop through set of error codes
            errorCodes = mergedInfo[studentIndex][3]
            if allErrorCodes[errorCodeIndex] in errorCodes:
                cell.value = errorCodes[allErrorCodes[errorCodeIndex]]
                # Add gradient colors for better visualization
                if type(cell.value) == str:
                    colorGradient = int(str(cell.value)[ : str(cell.value).find(" ")])
                else:
                    colorGradient = cell.value
                hexColor = '#%02x%02x%02x' % ((int)(255 - ((colorGradient / maxError) * 255)), (int)(255 - ((colorGradient / maxError) * 155)), 255)
                cell.fill = PatternFill(start_color = str(hexColor)[1:], end_color = str(hexColor)[1:], fill_type = "solid")
            errorCodeIndex += 1  
        cell.alignment = Alignment(horizontal = 'center')
    studentIndex += 1
    
    
# Count warning message occurrence

# Title of the row
sheet.cell(row = len(processedStudents) + 2, column = 1).value = "Warning Message Occurrence"
sheet.cell(row = len(processedStudents) + 2, column = 1).font = Font(bold = True)
sheet.cell(row = len(processedStudents) + 2, column = 1).alignment = Alignment(horizontal = 'center')

# Fill the frequency of each warning message
errorFreq = []
for singleError in allErrorCodes:
    errorCounter = 0
    for processedStudent in processedStudents:
        if singleError in processedStudent[1]:
            errorCounter += processedStudent[1][singleError]
    errorFreq.append(errorCounter)

maxError = max(errorFreq)
errorIndex = 0
for row in sheet.iter_rows(min_row = len(processedStudents) + 2, min_col = 4, max_row = len(processedStudents) + 2, max_col = len(allErrorCodes) + 3):
    for cell in row:
        cell.value = errorFreq[errorIndex]
        cell.alignment = Alignment(horizontal = 'center')
         # Add gradient colors for better visualization
        hexColor = '#%02x%02x%02x' % (255, (int)(255 - ((cell.value / maxError) * 255)), (int)(255 - ((cell.value / maxError) * 255)))
        cell.fill = PatternFill(start_color = str(hexColor)[1:], end_color = str(hexColor)[1:], fill_type = "solid")
        errorIndex += 1
   

# Add code reference to excel
# Title of the row
sheet.cell(row = len(processedStudents) + 3, column = 1).value = "Code Reference"
sheet.cell(row = len(processedStudents) + 3, column = 1).font = Font(bold = True)
sheet.cell(row = len(processedStudents) + 3, column = 1).alignment = Alignment(horizontal = 'center')
refIndex = 0
for row in sheet.iter_rows(min_row = len(processedStudents) + 3, min_col = 4, max_row = len(processedStudents) + 3, max_col = len(allErrorCodes) + 3):
    for cell in row:
        cell.value = simpleCodeReference[refIndex][1]
        cell.alignment = Alignment(horizontal = 'center')
        refIndex += 1

# %%
processedStudents
# Out:
# [['s01', {'C0303': 2, 'C0103': 1, 'C0114': 1, 'W0127': 2}],
#  ['s02', {'C0303': 1, 'C0103': 1, 'C0114': 1}],
#  ['s04', {'W0622': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s05', {'C0103': 1, 'C0114': 1}],
#  ['s06', {'W0622': 1, 'C0103': 1, 'C0114': 1}],
#  ['s16', {'C0103': 1, 'C0114': 1}],
#  ['s17', {'C0103': 1, 'C0114': 1, 'R1724': 1}],
#  ['s19', {'C0103': 1, 'C0114': 1}],
#  ['s22', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'W1309': 2, 'R1724': 1}],
#  ['s23', {'C0303': 1, 'C0103': 1, 'C0114': 1}],
#  ['s24', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s25', {'C0303': 2, 'C0325': 1, 'C0103': 1, 'C0114': 1, 'W0127': 1}],
#  ['s26', {'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s27', {'C0303': 2, 'C0103': 1, 'C0114': 1}],
#  ['s31', {'C0103': 1, 'C0114': 1}],
#  ['s32', {'C0103': 1, 'C0114': 1}],
#  ['s34', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s37', {'C0303': 1, 'C0103': 1, 'C0114': 1}],
#  ['s38', {'C0103': 1, 'C0114': 1, 'W1309': 2}],
#  ['s39', {'C0303': 2, 'C0103': 1, 'C0114': 1}],
#  ['s46', {'C0303': 1, 'C0305': 1, 'C0103': 1, 'C0114': 1}],
#  ['s48', {'C0103': 1, 'C0114': 1}],
#  ['s49', {'C0103': 2, 'C0114': 1}],
#  ['s52', {'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s53', {'E0001': 1}],
#  ['s54', {'C0103': 1, 'C0114': 1}],
#  ['s58', {'C0103': 1, 'C0114': 1, 'W1309': 2}],
#  ['s59', {'C0325': 1, 'C0103': 1, 'C0114': 1, 'R0801': 1}],
#  ['s100', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1, 'E0602': 2}],
#  ['s105', {'C0303': 2, 'C0103': 1, 'C0114': 1}],
#  ['s112', {'C0325': 1, 'C0103': 1, 'C0114': 1}],
#  ['s113', {'C0103': 1, 'C0114': 1}],
#  ['s114', {'C0103': 1, 'C0114': 1, 'W1309': 2}],
#  ['s115', {'C0303': 2, 'C0103': 1, 'C0114': 1, 'R1724': 1}],
#  ['s116', {'C0103': 1, 'C0114': 1}],
#  ['s118', {'C0301': 1, 'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s120', {'C0103': 1, 'C0114': 1}],
#  ['s121', {'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s123', {'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s124', {'C0325': 3, 'C0103': 1, 'C0114': 1}],
#  ['s126', {'C0103': 1, 'C0114': 1, 'E0602': 2}],
#  ['s127', {'C0301': 1, 'C0103': 1, 'C0114': 1}],
#  ['s129', {'W0311': 1, 'C0303': 1, 'C0103': 1, 'C0114': 1, 'R1716': 1}],
#  ['s137', {'C0103': 1, 'C0114': 1, 'E0602': 1}]]

# %%
# Fill in the information of each student (Hyperstyle)

# Define the level of numbers of errors (for visualizarion later)
maxError = 0
for processedStudent in mergedInfo:
    if maxError < max(processedStudent[4].values()):
        maxError = max(processedStudent[4].values())
        
studentIndex = 0
for row in sheet.iter_rows(min_row = 2, min_col = len(simpleCodeReference) + 7, max_row = len(processedStudents) + 1, max_col = len(simpleCodeReference) + len(simpleCodeReferenceHyper) + 6):
    errorCodeIndex = 0
    for cell in row:
        # Loop through set of error codes
        errorCodes = mergedInfo[studentIndex][4] # map
        if simpleCodeReferenceHyper[errorCodeIndex][0] in errorCodes:
            cell.value = errorCodes[simpleCodeReferenceHyper[errorCodeIndex][0]]
            # Add gradient colors for better visualization
            hexColor = '#%02x%02x%02x' % ((int)(255 - ((cell.value / maxError) * 255)), (int)(255 - ((cell.value / maxError) * 155)), 255)
            cell.fill = PatternFill(start_color = str(hexColor)[1:], end_color = str(hexColor)[1:], fill_type = "solid")
        errorCodeIndex += 1  
        cell.alignment = Alignment(horizontal = 'center')
    studentIndex += 1
    
    
# Fill the frequency of each warning message
errorFreq = []
for singleError in simpleCodeReferenceHyper:
    errorCounter = 0
    for processedStudent in mergedInfo:
        if singleError[0] in processedStudent[4]:
            errorCounter += processedStudent[4][singleError[0]]
    errorFreq.append(errorCounter)

maxError = max(errorFreq)
errorIndex = 0
for row in sheet.iter_rows(min_row = len(processedStudents) + 2, min_col = len(simpleCodeReference) + 7, max_row = len(processedStudents) + 2, max_col = len(simpleCodeReference) + len(simpleCodeReferenceHyper) + 6):
    for cell in row:
        cell.value = errorFreq[errorIndex]
        cell.alignment = Alignment(horizontal = 'center')
         # Add gradient colors for better visualization
        hexColor = '#%02x%02x%02x' % (255, (int)(255 - ((cell.value / maxError) * 255)), (int)(255 - ((cell.value / maxError) * 255)))
        cell.fill = PatternFill(start_color = str(hexColor)[1:], end_color = str(hexColor)[1:], fill_type = "solid")
        errorIndex += 1
        
        
# Add code reference to excel
refIndex = 0
for row in sheet.iter_rows(min_row = len(processedStudents) + 3, min_col = len(simpleCodeReference) + 7, max_row = len(processedStudents) + 3, max_col = len(simpleCodeReference) + len(simpleCodeReferenceHyper) + 6):
    for cell in row:
        cell.value = simpleCodeReferenceHyper[refIndex][1]
        cell.alignment = Alignment(horizontal = 'center')
        refIndex += 1

# %%
# Add some comments
sheet.cell(row = len(processedStudents) + 5, column = 4).value = "Dash (-) means Hyperstyle does not detect the same error if we can find the mapping rule."

# %%
workbook.save(filename="Week3_Merged_Meaning.xlsx")
