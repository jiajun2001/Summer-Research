# %%
# This is the mergedRule dictionary.
# For each key-value pair:
# The key is the Pylint error code and the value(list) contains its corresponding Hyperstyle error codes
mergedRule = {
    "W0622": ["A001"], 
    "W0612": ["B007"], 
    "C0301": ["C001", "E501"], 
    "W0311": ["E111", "E113", "E999", "W0311"], 
    "C0103": ["E741", "N816"], 
    "E0601": ["F821"], 
    "C0325": ["WPS313","C0325"],
    "W1309": ["W1309"],
    "E0001": ["E0001"],
    "C0305": ["C0305"],
    "E0602": ["E0602"],
    "R1716": ["R1716"],
    "W0127": ["W0127"]
}

errorCodeExcluded = []
for pCode in mergedRule.keys():
    for hCode in mergedRule[pCode]:
        errorCodeExcluded.append(hCode)

# %%
# Read the PylintOutput file
pylintOutput = open("/Users/apple/Desktop/SummerResearch/Week3/pylintOutput_Dataset2.txt", "a")

# Data Preprocess Stage
pylintOutput.write("************")
pylintOutput.close()

# Store Each line of the Pylint Outcome
pylintOutput = open("/Users/apple/Desktop/SummerResearch/Week3/pylintOutput_Dataset2.txt")
lines = []
while True:
    line = pylintOutput.readline()
    lines.append(line)
    if ("" == line):
        break

# Categorize each student's warning message 
students = []
student = []
for line in lines:
    if line[0:12] == "************":
        students.append(student)
        student = []
    student.append(line)
students.pop(0)

# Process each student
# single_outcome = ['Student_ID', 'error code 1', 'error code 2', ...]
# outcome = [single_outcome1, single_outcome2, ...]

codeReference = set()
outcome = []
for student in students:
    single_outcome = []
    # Get the Student ID first
    indexOfStudentID = student[0].find("Module") + 15
    single_outcome.append(student[0][indexOfStudentID : ].strip('\n'))
    single_outcome.insert(0, int(student[0][indexOfStudentID : ].strip('\n')))
    
    # Get the error code of this student
    messages = student[1 : ]
    for message in messages:
        tokens = message.split() 
        # Pick the warning code
        for token in tokens:
            if (len(token) == 6) and (token[0].isalpha()) and (token[1 : 4].isdigit()) and token[-1] == ':':
                single_outcome.append(token[0 : 5])
                codeReference.add(message[message.find(token[0 : 5]):].strip('\n'))
    outcome.append(single_outcome)

# Sort elements based on students' ID
outcome.sort(key = lambda x:x[0])
for e in outcome:
    e.pop(0)
    
# Find and sort all unique warning code alphabetically 
allErrorCodeSet = set()
# studentInfo = ['Student_ID', 'error code 1', 'error code 2', ....]
for studentInfo in outcome:
    for i in range(1, len(studentInfo)):
        allErrorCodeSet.add(studentInfo[i])
        
allErrorCodes = list(allErrorCodeSet)
allErrorCodes.sort()

# Count the number of each warning code for each student
# processedStudent = [Student_ID, {"c0001": 2, "w0001": 3, ...}]
# processedStudents = [processedStudent1, processedStudent2, ...]

processedStudents = []
for single_outcome in outcome:
    processedStudent = [single_outcome[0]]
    frequencyMap = {}
    for i in range(1, len(single_outcome)):
        if single_outcome[i] not in frequencyMap:
            frequencyMap[single_outcome[i]] = 1
        else:
            frequencyMap[single_outcome[i]] += 1
    processedStudent.append(frequencyMap)
    processedStudents.append(processedStudent)
    
processedStudents
# Out:
# [['0',
#   {'C0303': 16,
#    'C0301': 14,
#    'W0311': 3,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 31,
#    'C0116': 10,
#    'W0613': 2,
#    'W0603': 3,
#    'W0702': 1,
#    'R1705': 2,
#    'C0200': 1}],
#  ['1',
#   {'C0303': 13,
#    'C0301': 14,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 27,
#    'C0116': 10,
#    'W0613': 4,
#    'W0603': 2,
#    'C0200': 1,
#    'R1710': 1}],
#  ['2',
#   {'C0303': 14,
#    'C0301': 14,
#    'W0105': 6,
#    'C0103': 25,
#    'C0116': 10,
#    'W0613': 5,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 2,
#    'C0200': 1,
#    'R1710': 1}],
#  ['3',
#   {'C0303': 13,
#    'C0301': 14,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 27,
#    'C0116': 10,
#    'W0613': 1,
#    'R1710': 1,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'W0621': 1}],
#  ['4',
#   {'C0301': 2,
#    'C0303': 15,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1705': 1,
#    'C0103': 6,
#    'W0404': 1}],
#  ['5',
#   {'C0303': 6,
#    'C0301': 17,
#    'W0105': 6,
#    'C0103': 20,
#    'C0116': 10,
#    'W0613': 4,
#    'W0603': 2,
#    'R1705': 1,
#    'R1710': 1}],
#  ['6',
#   {'C0303': 15,
#    'C0301': 14,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 18,
#    'C0116': 10,
#    'W0613': 5,
#    'R1710': 2,
#    'W0622': 3,
#    'W0603': 2,
#    'C0200': 1,
#    'W0612': 1}],
#  ['7',
#   {'C0301': 3,
#    'C0303': 2,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 6,
#    'W0404': 1}],
#  ['8',
#   {'C0303': 14,
#    'C0301': 14,
#    'W0105': 6,
#    'C0103': 23,
#    'C0116': 10,
#    'W0613': 7,
#    'C0200': 1,
#    'W0603': 1,
#    'W0612': 4,
#    'W0621': 1,
#    'R1710': 1}],
#  ['9',
#   {'C0303': 23,
#    'C0301': 14,
#    'W0311': 1,
#    'W0105': 6,
#    'C0103': 20,
#    'C0116': 10,
#    'W0613': 4,
#    'R1710': 2,
#    'W0603': 2,
#    'R1705': 1,
#    'C0200': 1,
#    'R0801': 157}],
#  ['10',
#   {'C0303': 21,
#    'C0301': 14,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 30,
#    'C0116': 10,
#    'W0613': 4,
#    'R1710': 2,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0200': 2}],
#  ['11',
#   {'C0301': 2,
#    'C0303': 13,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 5,
#    'W0404': 1}],
#  ['12',
#   {'C0303': 27,
#    'C0301': 14,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 20,
#    'C0116': 10,
#    'W0613': 5,
#    'C0200': 2,
#    'W0603': 2,
#    'W0702': 1,
#    'R1710': 1}],
#  ['13',
#   {'C0303': 31,
#    'C0301': 14,
#    'C0325': 2,
#    'W0311': 5,
#    'W0105': 6,
#    'C0103': 27,
#    'C0116': 10,
#    'W0613': 3,
#    'W0603': 2,
#    'C0200': 1,
#    'R1705': 1,
#    'R1710': 1}],
#  ['14',
#   {'C0303': 27,
#    'C0301': 14,
#    'W0311': 7,
#    'W0105': 6,
#    'C0103': 20,
#    'C0116': 10,
#    'W0613': 6,
#    'W0612': 1,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0200': 1,
#    'R1710': 1}],
#  ['15',
#   {'C0301': 2,
#    'C0303': 17,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0103': 4,
#    'W0404': 1}],
#  ['16',
#   {'C0303': 24,
#    'C0301': 14,
#    'C0325': 1,
#    'W0105': 6,
#    'C0103': 24,
#    'C0116': 10,
#    'W0613': 4,
#    'W0612': 1,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'R1710': 1}],
#  ['17',
#   {'C0303': 11,
#    'C0301': 16,
#    'W0105': 6,
#    'C0103': 21,
#    'C0116': 10,
#    'W0613': 4,
#    'W0603': 4,
#    'R1703': 1,
#    'R1705': 1,
#    'W0120': 1,
#    'W0622': 1,
#    'C0200': 1,
#    'R1710': 1}],
#  ['18',
#   {'C0303': 26,
#    'C0301': 14,
#    'W0311': 33,
#    'W0105': 6,
#    'C0103': 23,
#    'C0116': 10,
#    'W0613': 5,
#    'W0621': 3,
#    'W0612': 1,
#    'C0115': 1,
#    'W0601': 5,
#    'R0201': 4,
#    'E0601': 1,
#    'R1703': 1,
#    'R1705': 1,
#    'C0200': 1,
#    'R1710': 1}],
#  ['19',
#   {'C0303': 14,
#    'C0301': 14,
#    'W0311': 2,
#    'W0105': 6,
#    'C0103': 15,
#    'C0116': 10,
#    'W0613': 4,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0200': 1}],
#  ['20',
#   {'C0303': 15,
#    'C0301': 14,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 29,
#    'C0116': 10,
#    'W0613': 3,
#    'W0603': 2,
#    'R1705': 1,
#    'C0200': 1}],
#  ['21',
#   {'C0303': 15,
#    'C0301': 14,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 21,
#    'C0116': 10,
#    'W0613': 6,
#    'R1710': 1,
#    'W0603': 1,
#    'W0612': 1,
#    'C0413': 1,
#    'W0621': 1,
#    'R1705': 1,
#    'E1111': 3,
#    'W0611': 1}],
#  ['22',
#   {'C0301': 2,
#    'C0303': 17,
#    'C0325': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 5,
#    'R1703': 1,
#    'R1705': 1,
#    'W0404': 1,
#    'W0612': 1}],
#  ['23',
#   {'C0301': 2,
#    'C0303': 18,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1724': 1,
#    'C0103': 4,
#    'W0404': 1}],
#  ['24',
#   {'C0303': 21,
#    'C0301': 9,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 11,
#    'C0116': 4,
#    'R1710': 1,
#    'R1723': 1,
#    'W0612': 2,
#    'R1702': 1,
#    'W0621': 1,
#    'W0611': 1}],
#  ['25',
#   {'C0303': 19,
#    'C0301': 6,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 12,
#    'C0116': 4,
#    'R1710': 1,
#    'C0200': 1,
#    'W0621': 1,
#    'W0611': 1}],
#  ['26',
#   {'C0301': 6,
#    'C0303': 13,
#    'C0325': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 4,
#    'W0404': 1}],
#  ['27',
#   {'C0303': 12,
#    'C0301': 14,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 20,
#    'C0116': 10,
#    'W0613': 11,
#    'W0622': 1,
#    'W0612': 2,
#    'W0603': 1,
#    'R1705': 1,
#    'E1111': 3}],
#  ['28',
#   {'C0301': 2,
#    'C0303': 18,
#    'C0325': 2,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'W0622': 1,
#    'C0103': 4,
#    'C0121': 1,
#    'W0101': 1,
#    'W0404': 1}],
#  ['29',
#   {'C0301': 2,
#    'C0303': 21,
#    'C0325': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 6,
#    'W0404': 1}],
#  ['30',
#   {'C0301': 2,
#    'C0303': 33,
#    'W0311': 2,
#    'C0325': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1705': 1,
#    'C0103': 6,
#    'W0404': 1}],
#  ['31',
#   {'C0301': 2,
#    'C0303': 17,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 5,
#    'R1705': 1,
#    'W0404': 1}],
#  ['32',
#   {'C0301': 2,
#    'C0303': 19,
#    'C0325': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 5,
#    'R1705': 1,
#    'W0404': 1}],
#  ['33', {'E0001': 1}],
#  ['34',
#   {'C0301': 2,
#    'C0303': 17,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'W0101': 2,
#    'W0612': 3,
#    'C0103': 4,
#    'W0404': 1,
#    'E1121': 8}],
#  ['35',
#   {'C0301': 2,
#    'C0303': 13,
#    'W0311': 3,
#    'C0325': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0103': 5,
#    'W0404': 1,
#    'W0612': 1}],
#  ['36',
#   {'C0301': 2,
#    'C0303': 14,
#    'C0325': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 5,
#    'W0404': 1}],
#  ['37',
#   {'C0301': 2,
#    'C0303': 22,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 5,
#    'W0404': 1}],
#  ['38', {'E0001': 1}],
#  ['39',
#   {'C0301': 2,
#    'C0303': 30,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': 7,
#    'R1705': 1,
#    'W0404': 1}],
#  ['40', {'E0001': 1}],
#  ['41',
#   {'C0303': 21,
#    'C0301': 5,
#    'W0105': 4,
#    'C0413': 3,
#    'C0103': 13,
#    'C0116': 4,
#    'W0101': 1,
#    'W0612': 2,
#    'C0200': 1,
#    'W0621': 1,
#    'W0611': 2}],
#  ['42',
#   {'C0303': 13,
#    'C0301': 13,
#    'C0325': 1,
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': 21,
#    'C0116': 10,
#    'W0613': 5,
#    'W0622': 4,
#    'W0621': 1,
#    'W0603': 3,
#    'W0612': 1,
#    'R1703': 1,
#    'R1705': 3,
#    'R1710': 1}],
#  ['43',
#   {'C0303': 33,
#    'C0301': 5,
#    'W0311': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 9,
#    'C0116': 4,
#    'W0621': 2,
#    'R1710': 1,
#    'W0612': 1,
#    'W0611': 1}],
#  ['44',
#   {'C0303': 19,
#    'C0301': 5,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 13,
#    'C0116': 4,
#    'W0613': 1,
#    'E1111': 4,
#    'W0612': 3,
#    'W0621': 1,
#    'W0611': 2}],
#  ['45',
#   {'C0303': 17,
#    'C0301': 5,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 9,
#    'C0116': 4,
#    'R1710': 1,
#    'W0612': 2,
#    'W0621': 1,
#    'W0611': 1}],
#  ['46',
#   {'C0303': 20,
#    'C0301': 5,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 11,
#    'C0116': 4,
#    'R1710': 1,
#    'W0621': 2,
#    'W0612': 1,
#    'W0611': 1}],
#  ['47', {'E0001': 1}],
#  ['48',
#   {'C0303': 21,
#    'C0301': 5,
#    'W0301': 1,
#    'C0325': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 12,
#    'C0116': 4,
#    'C0200': 1,
#    'W0612': 5,
#    'E1111': 2,
#    'W0621': 1,
#    'W0611': 1}],
#  ['49',
#   {'C0303': 16,
#    'C0301': 6,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 12,
#    'C0116': 4,
#    'R1721': 2,
#    'R1710': 1,
#    'C0200': 3,
#    'R0914': 1,
#    'W0621': 1,
#    'W0611': 1}],
#  ['50',
#   {'C0303': 20,
#    'C0301': 5,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 9,
#    'C0116': 4,
#    'C0200': 2,
#    'W0612': 1,
#    'W0621': 1,
#    'W0611': 1}],
#  ['51',
#   {'C0303': 17,
#    'C0301': 10,
#    'W0105': 4,
#    'C0413': 1,
#    'C0116': 4,
#    'R1710': 1,
#    'C0103': 8,
#    'W0621': 1}],
#  ['52',
#   {'C0303': 18,
#    'C0301': 5,
#    'W0105': 4,
#    'C0413': 3,
#    'C0103': 12,
#    'C0116': 4,
#    'R1710': 1,
#    'W0404': 1,
#    'W0612': 2,
#    'W0621': 1,
#    'E1111': 2,
#    'W0611': 1,
#    'C0412': 1}],
#  ['53',
#   {'C0303': 21,
#    'C0301': 5,
#    'C0325': 2,
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 16,
#    'C0116': 4,
#    'R1710': 1,
#    'W0612': 3,
#    'E1111': 2,
#    'W0621': 1,
#    'W0611': 1}],
#  ['54', {'E0001': 1}],
#  ['55',
#   {'C0303': 25,
#    'C0301': 5,
#    'W0311': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 15,
#    'C0116': 4,
#    'R1710': 1,
#    'W0612': 4,
#    'E1111': 2,
#    'W0621': 1,
#    'W0611': 1}],
#  ['56',
#   {'C0303': 20,
#    'C0301': 5,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 10,
#    'C0116': 4,
#    'W0621': 1,
#    'W0611': 1}],
#  ['57',
#   {'C0303': 12,
#    'C0301': 5,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': 11,
#    'C0116': 4,
#    'W0612': 2,
#    'W0621': 1,
#    'W0611': 1}]]

# %%
# Get reference to the meaning of each warning code
simpleCodeReference = []
allErrorCodesCpy = list(allErrorCodes)
for ref in codeReference:
    singleSimpleCodeReference = []
    singleSimpleCodeReference.append(ref[0:5])
    start = ref.rfind('(') + 1
    end = ref.rfind(')')
    if start == 0 or end == -1:
        singleSimpleCodeReference.append(ref[8:])
    else:
        singleSimpleCodeReference.append(ref[start : end])
    if singleSimpleCodeReference[0] in allErrorCodesCpy: 
        simpleCodeReference.append(singleSimpleCodeReference)
        allErrorCodesCpy.remove(singleSimpleCodeReference[0])

# Sort error codes
simpleCodeReference.sort(key = lambda x:x[0])
simpleCodeReference
# Out:
# [['C0103', 'invalid-name'],
#  ['C0115', 'missing-class-docstring'],
#  ['C0116', 'missing-function-docstring'],
#  ['C0121', 'singleton-comparison'],
#  ['C0200', 'consider-using-enumerate'],
#  ['C0301', 'line-too-long'],
#  ['C0303', 'trailing-whitespace'],
#  ['C0304', 'missing-final-newline'],
#  ['C0325', 'superfluous-parens'],
#  ['C0412', 'ungrouped-imports'],
#  ['C0413', 'wrong-import-position'],
#  ['E0001', 'syntax-error'],
#  ['E0601', 'used-before-assignment'],
#  ['E1111', 'assignment-from-no-return'],
#  ['E1121', 'too-many-function-args'],
#  ['R0201', 'no-self-use'],
#  ['R0801', 'imilar lines in 13 files'],
#  ['R0914', 'too-many-locals'],
#  ['R1702', 'too-many-nested-blocks'],
#  ['R1703', 'simplifiable-if-statement'],
#  ['R1705', 'no-else-return'],
#  ['R1710', 'inconsistent-return-statements'],
#  ['R1721', 'unnecessary-comprehension'],
#  ['R1723', 'no-else-break'],
#  ['R1724', 'no-else-continue'],
#  ['W0101', 'unreachable'],
#  ['W0105', 'pointless-string-statement'],
#  ['W0120', 'useless-else-on-loop'],
#  ['W0301', 'unnecessary-semicolon'],
#  ['W0311', 'bad-indentation'],
#  ['W0404', 'reimported'],
#  ['W0601', 'global-variable-undefined'],
#  ['W0603', 'global-statement'],
#  ['W0611', 'unused-import'],
#  ['W0612', 'unused-variable'],
#  ['W0613', 'unused-argument'],
#  ['W0621', 'redefined-outer-name'],
#  ['W0622', 'redefined-builtin'],
#  ['W0702', 'bare-except']]

# %%
# Read the Hyperstyle JSON file
# import required module
from pathlib import Path
import json
 
# assign directory
directory = '/Users/apple/Desktop/SummerResearch/Week3/JSON_output2'
 
processedStudentsHyperstyle = []
errorCodeSet = set()
errorCode = []

# iterate over files in that directory
files = Path(directory).glob('*')
for file in files:
    sFile = str(file)
    if sFile[-4:] == "json":
        f = open(file)
        student = json.load(f)
        processedStudent = []
        # Append the name of the solution
        processedStudent.append((int)(sFile[str(file).find("solution") + 8 : sFile.find(".")]))
        processedStudent.append(sFile[str(file).find("solution") + 8 : sFile.find(".")])
        
        # Append the code quality and text quality
        processedStudent.append(student["quality"]["code"])
        processedStudent.append(student["quality"]["text"][student["quality"]["text"].rfind(": ") + 2 : ])
        
        # Collect the student error
        frequencyMap = {}
        for issue in student["issues"]:
            if issue["code"] not in frequencyMap:
                frequencyMap[issue["code"]] = 1
            else:
                frequencyMap[issue["code"]] += 1
        processedStudent.append(frequencyMap)
        processedStudentsHyperstyle.append(processedStudent)
        
        # Collect error codes
        for issue in student["issues"]:
            if issue["code"] not in errorCodeSet:
                errorCodeSet.add(issue["code"])
                singleErrorCode = [issue["code"], issue["text"], issue["category"], issue["difficulty"]]
                errorCode.append(singleErrorCode)
                
# Sort the outcome
processedStudentsHyperstyle.sort(key = lambda x:x[0])
for e in processedStudentsHyperstyle:
    e.pop(0)
# print(*processedStudentsHyperstyle,sep='\n')
errorCode.sort(key = lambda x:x[0])
print(*errorCode, sep = '\n')

# print(*processedStudentsHyperstyle,sep='\n')
# Out:
# ['A001', 'variable "next" is shadowing a python builtin', 'ERROR_PRONE', 'HARD']
# ['B007', "Loop control variable 'i' not used within the loop body. If this is intended, replace it with an underscore.", 'BEST_PRACTICES', 'MEDIUM']
# ['C002', 'Too long function (51 lines). Try to split it into smaller functions / methods. It will make your code easy to understand and less error prone.', 'BEST_PRACTICES', 'EASY']
# ['C0121', "Comparison 'dict[i] == False' should be 'dict[i] is False' if checking for the singleton value False, or 'not dict[i]' if testing for falsiness", 'BEST_PRACTICES', 'MEDIUM']
# ['C0200', 'Consider using enumerate instead of iterating with range and len', 'BEST_PRACTICES', 'MEDIUM']
# ['C0325', "Unnecessary parens after 'if' keyword", 'CODE_STYLE', 'EASY']
# ['C0412', 'Imports from package itertools are not grouped', 'CODE_STYLE', 'EASY']
# ['C405', 'Unnecessary list literal - rewrite as a set literal.', 'BEST_PRACTICES', 'MEDIUM']
# ['C414', 'Unnecessary list call within sorted().', 'BEST_PRACTICES', 'MEDIUM']
# ['C812', 'missing trailing comma', 'CODE_STYLE', 'EASY']
# ['C901', 'Cyclomatic complexity is too high (11). You can figure out how to simplify this code or split it into a set of small functions / methods. It will make your code easy to understand and less error prone.', 'COMPLEXITY', 'HARD']
# ['E0001', 'expected an indented block (<unknown>, line 196)', 'ERROR_PRONE', 'HARD']
# ['E0601', "Using variable 'index' before assignment", 'ERROR_PRONE', 'HARD']
# ['E111', 'indentation is not a multiple of     ', 'CODE_STYLE', 'EASY']
# ['E1111', 'Assigning result of a function call, where the function has no return', 'ERROR_PRONE', 'HARD']
# ['E112', 'expected an indented block', 'CODE_STYLE', 'EASY']
# ['E1121', 'Too many positional arguments for function call', 'ERROR_PRONE', 'HARD']
# ['E114', 'indentation is not a multiple of      (comment)', 'CODE_STYLE', 'EASY']
# ['E115', 'expected an indented block (comment)', 'CODE_STYLE', 'EASY']
# ['E116', 'unexpected indentation (comment)', 'CODE_STYLE', 'EASY']
# ['E117', 'over-indented', 'CODE_STYLE', 'EASY']
# ['E201', "whitespace after '('", 'CODE_STYLE', 'EASY']
# ['E203', "whitespace before ','", 'CODE_STYLE', 'EASY']
# ['E211', "whitespace before '('", 'CODE_STYLE', 'EASY']
# ['E221', 'multiple spaces before operator', 'CODE_STYLE', 'EASY']
# ['E222', 'multiple spaces after operator', 'CODE_STYLE', 'EASY']
# ['E225', 'missing whitespace around operator', 'CODE_STYLE', 'EASY']
# ['E226', 'missing whitespace around arithmetic operator', 'CODE_STYLE', 'EASY']
# ['E228', 'missing whitespace around modulo operator', 'CODE_STYLE', 'EASY']
# ['E231', "missing whitespace after ','", 'CODE_STYLE', 'EASY']
# ['E241', "multiple spaces after ','", 'CODE_STYLE', 'EASY']
# ['E251', 'unexpected spaces around keyword / parameter equals', 'CODE_STYLE', 'EASY']
# ['E261', 'at least two spaces before inline comment', 'CODE_STYLE', 'EASY']
# ['E262', "inline comment should start with '# '", 'CODE_STYLE', 'EASY']
# ['E265', "block comment should start with '# '", 'CODE_STYLE', 'EASY']
# ['E271', 'multiple spaces after keyword', 'CODE_STYLE', 'EASY']
# ['E272', 'multiple spaces before keyword', 'CODE_STYLE', 'EASY']
# ['E501', 'Too long line (157 symbols). Try to split it into smaller lines. It will make your code easy to understand.', 'CODE_STYLE', 'EASY']
# ['E701', 'multiple statements on one line (colon)', 'CODE_STYLE', 'EASY']
# ['E703', 'statement ends with a semicolon', 'CODE_STYLE', 'EASY']
# ['E712', "comparison to False should be 'if cond is False:' or 'if not cond:'", 'CODE_STYLE', 'EASY']
# ['E713', "test for membership should be 'not in'", 'CODE_STYLE', 'EASY']
# ['E722', "do not use bare 'except'", 'CODE_STYLE', 'EASY']
# ['E741', "ambiguous variable name 'l'", 'CODE_STYLE', 'EASY']
# ['E902', 'TokenError: EOF in multi-line statement', 'CODE_STYLE', 'EASY']
# ['E999', 'IndentationError: expected an indented block', 'CODE_STYLE', 'EASY']
# ['F401', "'copy' imported but unused", 'BEST_PRACTICES', 'MEDIUM']
# ['F841', "local variable 'prev_max' is assigned to but never used", 'BEST_PRACTICES', 'MEDIUM']
# ['H601', 'Lack of cohesion is too high (100%). Cohesion measures the strength of relationship between pieces of functionality within a given module. When lack of cohesion is low, the methods and variables of the class are co-dependent and hang together as a logical whole. However, if the task requires implementing classes without methods, the lack of cohesion always will be high since all variables will be in-dependent. Please, ignore this issue if the task requires implement an empty class (without any methods).', 'COMPLEXITY', 'HARD']
# ['N806', "variable 'flatTup' in function should be lowercase", 'CODE_STYLE', 'EASY']
# ['R0201', 'Method could be a function', 'BEST_PRACTICES', 'MEDIUM']
# ['R1703', "The if statement can be replaced with 'return bool(test)'", 'BEST_PRACTICES', 'MEDIUM']
# ['R1710', 'Either all return statements in a function should return an expression, or none of them should.', 'BEST_PRACTICES', 'MEDIUM']
# ['R1721', 'Unnecessary use of a comprehension. Instead of using an identity comprehension, consider using the list, dict or set constructor. It is faster and simpler. For example, instead of {key: value for key, value in list_of_tuples} use dict(list_of_tuples).', 'BEST_PRACTICES', 'MEDIUM']
# ['R503', 'you should add explicit return at end of the function if function have return value except None', 'ERROR_PRONE', 'HARD']
# ['R504', 'you shouldn`t assign value to variable if it will be use only as return value', 'BEST_PRACTICES', 'MEDIUM']
# ['SC100', "Possibly misspelt word: '2''''", 'INFO', 'EASY']
# ['SC200', "Possibly misspelt word: 'q1'", 'INFO', 'EASY']
# ['W0101', 'Unreachable code', 'ERROR_PRONE', 'HARD']
# ['W0105', 'String statement has no effect', 'ERROR_PRONE', 'HARD']
# ['W0120', 'Else clause on loop without a break statement', 'BEST_PRACTICES', 'MEDIUM']
# ['W0311', 'Bad indentation. Found 7 spaces, expected 8', 'CODE_STYLE', 'EASY']
# ['W0404', "Reimport 'copy' (imported line 31)", 'BEST_PRACTICES', 'MEDIUM']
# ['W0601', "Global variable 'size' undefined at the module level", 'BEST_PRACTICES', 'MEDIUM']
# ['W0611', 'Unused import copy', 'BEST_PRACTICES', 'MEDIUM']
# ['W0612', "Unused variable 'covered'", 'BEST_PRACTICES', 'MEDIUM']
# ['W0613', "Unused argument 'val'", 'BEST_PRACTICES', 'MEDIUM']
# ['W0621', "Redefining name 's' from outer scope (line 157)", 'BEST_PRACTICES', 'MEDIUM']
# ['W0702', 'No exception type(s) specified', 'BEST_PRACTICES', 'MEDIUM']
# ['W391', 'blank line at end of file', 'CODE_STYLE', 'EASY']
# ['WPS121', 'Found usage of a variable marked as unused: _sum', 'CODE_STYLE', 'EASY']
# ['WPS122', 'Found all unused variables definition: _sum', 'CODE_STYLE', 'EASY']
# ['WPS204', 'Found overused expression: costs[n]; used 5 > 4', 'COMPLEXITY', 'HARD']
# ['WPS220', 'Found too deep nesting: 24 > 20', 'COMPLEXITY', 'HARD']
# ['WPS231', 'Found function with too much cognitive complexity: 20 > 12', 'COMPLEXITY', 'HARD']
# ['WPS237', 'Found a too complex `f` string', 'COMPLEXITY', 'HARD']
# ['WPS313', 'Found parenthesis immediately after a keyword', 'CODE_STYLE', 'EASY']
# ['WPS331', 'Found variables that are only used for `return`: n', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS336', 'Found explicit string concatenation', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS350', 'Found usable augmented assign pattern. You can use shorthand notation if the left and right parts of the expression have the same variable, e.g. x = x + 2 is the same with x += 2.', 'CODE_STYLE', 'EASY']
# ['WPS428', 'Found statement that has no effect', 'ERROR_PRONE', 'HARD']
# ['WPS432', "Found a magic number: 15. The use of unnamed magic numbers in code hides the developers' intent in choosing that number, increases opportunities for subtle errors and makes it more difficult for the program to be adapted and extended in the future. However, for small programs it can be allowed, but it is better to use constants instead of magic numbers.", 'INFO', 'EASY']
# ['WPS440', 'Found block variables overlap: i', 'ERROR_PRONE', 'HARD']
# ['WPS441', 'Found control variable used after block: subset', 'ERROR_PRONE', 'HARD']
# ['WPS444', 'Found incorrect keyword condition', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS458', 'Found imports collision: itertools', 'ERROR_PRONE', 'HARD']
# ['WPS462', 'Wrong multiline string usage', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS464', 'Found empty comment', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS500', 'Found `else` in a loop without `break`', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS503', 'Found useless returning `else` statement', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS504', 'Found negated condition', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS507', 'Found useless `len()` compare', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS508', 'Found incorrect `not` with compare usage', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS513', 'Found implicit `elif` condition', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS519', 'Found implicit `sum()` call', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS520', 'Found compare with falsy constant', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS528', 'Found implicit `.items()` usage', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS529', 'Found implicit `.get()` dict usage', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS531', 'Found simplifiable returning `if` condition in a function', 'BEST_PRACTICES', 'MEDIUM']

# %%
# Get reference to the meaning of each warning code
simpleCodeReferenceHyper = []
for code in errorCode:
    if code[0] not in errorCodeExcluded:
        simpleCodeReferenceHyper.append(code)
print(*simpleCodeReferenceHyper, sep="\n")
# Out:
# ['C002', 'Too long function (51 lines). Try to split it into smaller functions / methods. It will make your code easy to understand and less error prone.', 'BEST_PRACTICES', 'EASY']
# ['C0121', "Comparison 'dict[i] == False' should be 'dict[i] is False' if checking for the singleton value False, or 'not dict[i]' if testing for falsiness", 'BEST_PRACTICES', 'MEDIUM']
# ['C0200', 'Consider using enumerate instead of iterating with range and len', 'BEST_PRACTICES', 'MEDIUM']
# ['C0412', 'Imports from package itertools are not grouped', 'CODE_STYLE', 'EASY']
# ['C405', 'Unnecessary list literal - rewrite as a set literal.', 'BEST_PRACTICES', 'MEDIUM']
# ['C414', 'Unnecessary list call within sorted().', 'BEST_PRACTICES', 'MEDIUM']
# ['C812', 'missing trailing comma', 'CODE_STYLE', 'EASY']
# ['C901', 'Cyclomatic complexity is too high (11). You can figure out how to simplify this code or split it into a set of small functions / methods. It will make your code easy to understand and less error prone.', 'COMPLEXITY', 'HARD']
# ['E0601', "Using variable 'index' before assignment", 'ERROR_PRONE', 'HARD']
# ['E1111', 'Assigning result of a function call, where the function has no return', 'ERROR_PRONE', 'HARD']
# ['E112', 'expected an indented block', 'CODE_STYLE', 'EASY']
# ['E1121', 'Too many positional arguments for function call', 'ERROR_PRONE', 'HARD']
# ['E114', 'indentation is not a multiple of      (comment)', 'CODE_STYLE', 'EASY']
# ['E115', 'expected an indented block (comment)', 'CODE_STYLE', 'EASY']
# ['E116', 'unexpected indentation (comment)', 'CODE_STYLE', 'EASY']
# ['E117', 'over-indented', 'CODE_STYLE', 'EASY']
# ['E201', "whitespace after '('", 'CODE_STYLE', 'EASY']
# ['E203', "whitespace before ','", 'CODE_STYLE', 'EASY']
# ['E211', "whitespace before '('", 'CODE_STYLE', 'EASY']
# ['E221', 'multiple spaces before operator', 'CODE_STYLE', 'EASY']
# ['E222', 'multiple spaces after operator', 'CODE_STYLE', 'EASY']
# ['E225', 'missing whitespace around operator', 'CODE_STYLE', 'EASY']
# ['E226', 'missing whitespace around arithmetic operator', 'CODE_STYLE', 'EASY']
# ['E228', 'missing whitespace around modulo operator', 'CODE_STYLE', 'EASY']
# ['E231', "missing whitespace after ','", 'CODE_STYLE', 'EASY']
# ['E241', "multiple spaces after ','", 'CODE_STYLE', 'EASY']
# ['E251', 'unexpected spaces around keyword / parameter equals', 'CODE_STYLE', 'EASY']
# ['E261', 'at least two spaces before inline comment', 'CODE_STYLE', 'EASY']
# ['E262', "inline comment should start with '# '", 'CODE_STYLE', 'EASY']
# ['E265', "block comment should start with '# '", 'CODE_STYLE', 'EASY']
# ['E271', 'multiple spaces after keyword', 'CODE_STYLE', 'EASY']
# ['E272', 'multiple spaces before keyword', 'CODE_STYLE', 'EASY']
# ['E701', 'multiple statements on one line (colon)', 'CODE_STYLE', 'EASY']
# ['E703', 'statement ends with a semicolon', 'CODE_STYLE', 'EASY']
# ['E712', "comparison to False should be 'if cond is False:' or 'if not cond:'", 'CODE_STYLE', 'EASY']
# ['E713', "test for membership should be 'not in'", 'CODE_STYLE', 'EASY']
# ['E722', "do not use bare 'except'", 'CODE_STYLE', 'EASY']
# ['E902', 'TokenError: EOF in multi-line statement', 'CODE_STYLE', 'EASY']
# ['F401', "'copy' imported but unused", 'BEST_PRACTICES', 'MEDIUM']
# ['F841', "local variable 'prev_max' is assigned to but never used", 'BEST_PRACTICES', 'MEDIUM']
# ['H601', 'Lack of cohesion is too high (100%). Cohesion measures the strength of relationship between pieces of functionality within a given module. When lack of cohesion is low, the methods and variables of the class are co-dependent and hang together as a logical whole. However, if the task requires implementing classes without methods, the lack of cohesion always will be high since all variables will be in-dependent. Please, ignore this issue if the task requires implement an empty class (without any methods).', 'COMPLEXITY', 'HARD']
# ['N806', "variable 'flatTup' in function should be lowercase", 'CODE_STYLE', 'EASY']
# ['R0201', 'Method could be a function', 'BEST_PRACTICES', 'MEDIUM']
# ['R1703', "The if statement can be replaced with 'return bool(test)'", 'BEST_PRACTICES', 'MEDIUM']
# ['R1710', 'Either all return statements in a function should return an expression, or none of them should.', 'BEST_PRACTICES', 'MEDIUM']
# ['R1721', 'Unnecessary use of a comprehension. Instead of using an identity comprehension, consider using the list, dict or set constructor. It is faster and simpler. For example, instead of {key: value for key, value in list_of_tuples} use dict(list_of_tuples).', 'BEST_PRACTICES', 'MEDIUM']
# ['R503', 'you should add explicit return at end of the function if function have return value except None', 'ERROR_PRONE', 'HARD']
# ['R504', 'you shouldn`t assign value to variable if it will be use only as return value', 'BEST_PRACTICES', 'MEDIUM']
# ['SC100', "Possibly misspelt word: '2''''", 'INFO', 'EASY']
# ['SC200', "Possibly misspelt word: 'q1'", 'INFO', 'EASY']
# ['W0101', 'Unreachable code', 'ERROR_PRONE', 'HARD']
# ['W0105', 'String statement has no effect', 'ERROR_PRONE', 'HARD']
# ['W0120', 'Else clause on loop without a break statement', 'BEST_PRACTICES', 'MEDIUM']
# ['W0404', "Reimport 'copy' (imported line 31)", 'BEST_PRACTICES', 'MEDIUM']
# ['W0601', "Global variable 'size' undefined at the module level", 'BEST_PRACTICES', 'MEDIUM']
# ['W0611', 'Unused import copy', 'BEST_PRACTICES', 'MEDIUM']
# ['W0612', "Unused variable 'covered'", 'BEST_PRACTICES', 'MEDIUM']
# ['W0613', "Unused argument 'val'", 'BEST_PRACTICES', 'MEDIUM']
# ['W0621', "Redefining name 's' from outer scope (line 157)", 'BEST_PRACTICES', 'MEDIUM']
# ['W0702', 'No exception type(s) specified', 'BEST_PRACTICES', 'MEDIUM']
# ['W391', 'blank line at end of file', 'CODE_STYLE', 'EASY']
# ['WPS121', 'Found usage of a variable marked as unused: _sum', 'CODE_STYLE', 'EASY']
# ['WPS122', 'Found all unused variables definition: _sum', 'CODE_STYLE', 'EASY']
# ['WPS204', 'Found overused expression: costs[n]; used 5 > 4', 'COMPLEXITY', 'HARD']
# ['WPS220', 'Found too deep nesting: 24 > 20', 'COMPLEXITY', 'HARD']
# ['WPS231', 'Found function with too much cognitive complexity: 20 > 12', 'COMPLEXITY', 'HARD']
# ['WPS237', 'Found a too complex `f` string', 'COMPLEXITY', 'HARD']
# ['WPS331', 'Found variables that are only used for `return`: n', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS336', 'Found explicit string concatenation', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS350', 'Found usable augmented assign pattern. You can use shorthand notation if the left and right parts of the expression have the same variable, e.g. x = x + 2 is the same with x += 2.', 'CODE_STYLE', 'EASY']
# ['WPS428', 'Found statement that has no effect', 'ERROR_PRONE', 'HARD']
# ['WPS432', "Found a magic number: 15. The use of unnamed magic numbers in code hides the developers' intent in choosing that number, increases opportunities for subtle errors and makes it more difficult for the program to be adapted and extended in the future. However, for small programs it can be allowed, but it is better to use constants instead of magic numbers.", 'INFO', 'EASY']
# ['WPS440', 'Found block variables overlap: i', 'ERROR_PRONE', 'HARD']
# ['WPS441', 'Found control variable used after block: subset', 'ERROR_PRONE', 'HARD']
# ['WPS444', 'Found incorrect keyword condition', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS458', 'Found imports collision: itertools', 'ERROR_PRONE', 'HARD']
# ['WPS462', 'Wrong multiline string usage', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS464', 'Found empty comment', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS500', 'Found `else` in a loop without `break`', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS503', 'Found useless returning `else` statement', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS504', 'Found negated condition', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS507', 'Found useless `len()` compare', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS508', 'Found incorrect `not` with compare usage', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS513', 'Found implicit `elif` condition', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS519', 'Found implicit `sum()` call', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS520', 'Found compare with falsy constant', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS528', 'Found implicit `.items()` usage', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS529', 'Found implicit `.get()` dict usage', 'BEST_PRACTICES', 'MEDIUM']
# ['WPS531', 'Found simplifiable returning `if` condition in a function', 'BEST_PRACTICES', 'MEDIUM']

# %%
# Merge students' error message from Pylint output and HyperStyle output based on their meanings
# mergedInfo[x] = [ID, Code Quality, Text Quality, {Pylint Error Count Map}, {Hyperstyle Error Count Map}, [Overlapped Hyperstyle ]]
mergedInfo = []
for i in range(len(processedStudents)):
    singleMergedInfo = [processedStudents[i][0], processedStudentsHyperstyle[i][1], processedStudentsHyperstyle[i][2]]
    # Merge common error codes
    pylintStudentError = dict(processedStudents[i][1])
    hyperStudentError = dict(processedStudentsHyperstyle[i][3])
    for pylintMapError in mergedRule.keys():
        if pylintMapError in pylintStudentError:
            hyperMapError = mergedRule[pylintMapError]
            additionalInfo = " ( Hyperstyle: "
            for oneHyperMapError in hyperMapError:
                if oneHyperMapError in hyperStudentError:
                    additionalInfo += str(oneHyperMapError) + ": " + str(hyperStudentError[oneHyperMapError]) + " "
                    hyperStudentError.pop(oneHyperMapError)
            if additionalInfo != " ( Hyperstyle: ":
                pylintStudentError[pylintMapError] = str(pylintStudentError[pylintMapError]) + additionalInfo + ")"
            else: 
                pylintStudentError[pylintMapError] = str(pylintStudentError[pylintMapError]) + " (-)"
    singleMergedInfo.append(pylintStudentError)
    singleMergedInfo.append(hyperStudentError)
    mergedInfo.append(singleMergedInfo)
mergedInfo
# Out:
# [['0',
#   'BAD',
#   'BAD',
#   {'C0303': 16,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'W0311': '3 ( Hyperstyle: W0311: 3 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '31 (-)',
#    'C0116': 10,
#    'W0613': 2,
#    'W0603': 3,
#    'W0702': 1,
#    'R1705': 2,
#    'C0200': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 2,
#    'SC200': 19,
#    'E261': 16,
#    'SC100': 2,
#    'E265': 2,
#    'WPS507': 1,
#    'W0702': 1,
#    'E722': 1,
#    'WPS440': 2,
#    'WPS529': 2,
#    'E231': 9,
#    'C0200': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['1',
#   'BAD',
#   'BAD',
#   {'C0303': 13,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '27 (-)',
#    'C0116': 10,
#    'W0613': 4,
#    'W0603': 2,
#    'C0200': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 4,
#    'SC200': 14,
#    'WPS529': 3,
#    'E261': 15,
#    'SC100': 2,
#    'E265': 2,
#    'WPS440': 2,
#    'E231': 9,
#    'R1710': 1,
#    'C0200': 1,
#    'R503': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['2',
#   'BAD',
#   'BAD',
#   {'C0303': 14,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'W0105': 6,
#    'C0103': '25 (-)',
#    'C0116': 10,
#    'W0613': 5,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 2,
#    'C0200': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 5,
#    'E261': 44,
#    'E262': 32,
#    'SC200': 15,
#    'SC100': 3,
#    'WPS529': 2,
#    'E265': 2,
#    'WPS507': 1,
#    'R1703': 1,
#    'WPS503': 2,
#    'WPS440': 2,
#    'WPS531': 1,
#    'E231': 9,
#    'R1710': 1,
#    'C0200': 1,
#    'R503': 1,
#    'WPS432': 2}],
#  ['3',
#   'BAD',
#   'BAD',
#   {'C0303': 13,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '27 (-)',
#    'C0116': 10,
#    'W0613': 1,
#    'R1710': 1,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'W0621': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 1,
#    'SC200': 18,
#    'WPS331': 6,
#    'R504': 6,
#    'R1710': 1,
#    'R503': 2,
#    'WPS528': 3,
#    'E228': 2,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'R1703': 1,
#    'WPS503': 1,
#    'WPS350': 1,
#    'WPS440': 2,
#    'W0621': 1,
#    'E231': 10,
#    'E226': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['4',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 15,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1705': 1,
#    'C0103': '6 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 81,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 2,
#    'WPS529': 2,
#    'WPS507': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 3,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS528': 2,
#    'E115': 1,
#    'E262': 1}],
#  ['5',
#   'BAD',
#   'BAD',
#   {'C0303': 6,
#    'C0301': '17 ( Hyperstyle: E501: 11 )',
#    'W0105': 6,
#    'C0103': '20 (-)',
#    'C0116': 10,
#    'W0613': 4,
#    'W0603': 2,
#    'R1705': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 4,
#    'SC200': 15,
#    'WPS122': 4,
#    'WPS519': 2,
#    'WPS121': 6,
#    'SC100': 2,
#    'E265': 2,
#    'WPS507': 1,
#    'WPS440': 2,
#    'R1710': 1,
#    'R503': 1,
#    'E231': 1,
#    'WPS529': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['6',
#   'BAD',
#   'BAD',
#   {'C0303': 15,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '18 (-)',
#    'C0116': 10,
#    'W0613': 5,
#    'R1710': 2,
#    'W0622': '3 ( Hyperstyle: A001: 3 )',
#    'W0603': 2,
#    'C0200': 1,
#    'W0612': '1 (-)'},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 5,
#    'SC200': 14,
#    'R1710': 2,
#    'R503': 2,
#    'WPS528': 1,
#    'E228': 2,
#    'WPS331': 2,
#    'R504': 2,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'E231': 10,
#    'WPS529': 1,
#    'WPS440': 2,
#    'W0612': 1,
#    'C0200': 1,
#    'E226': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['7',
#   'BAD',
#   'BAD',
#   {'C0301': '3 ( Hyperstyle: E501: 1 )',
#    'C0303': 2,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '6 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'SC200': 81,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 2,
#    'WPS529': 2,
#    'W0404': 1,
#    'WPS440': 3,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS528': 1,
#    'WPS513': 1,
#    'WPS220': 1,
#    'E262': 1}],
#  ['8',
#   'BAD',
#   'BAD',
#   {'C0303': 14,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'W0105': 6,
#    'C0103': '23 (-)',
#    'C0116': 10,
#    'W0613': 7,
#    'C0200': 1,
#    'W0603': 1,
#    'W0612': '4 (-)',
#    'W0621': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 7,
#    'SC200': 22,
#    'WPS331': 2,
#    'R504': 2,
#    'C0200': 1,
#    'E231': 14,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'WPS428': 3,
#    'W0612': 4,
#    'WPS440': 2,
#    'E225': 2,
#    'E226': 2,
#    'R1710': 1,
#    'W0621': 1,
#    'R503': 1,
#    'E203': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['9',
#   'BAD',
#   'BAD',
#   {'C0303': 23,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'W0311': '1 ( Hyperstyle: E111: 1 )',
#    'W0105': 6,
#    'C0103': '20 (-)',
#    'C0116': 10,
#    'W0613': 4,
#    'R1710': 2,
#    'W0603': 2,
#    'R1705': 1,
#    'C0200': 1,
#    'R0801': 157},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 4,
#    'SC200': 15,
#    'R1710': 2,
#    'R503': 2,
#    'WPS528': 2,
#    'E225': 12,
#    'E228': 2,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'WPS507': 1,
#    'WPS531': 2,
#    'E231': 14,
#    'WPS440': 2,
#    'WPS503': 1,
#    'C0200': 1,
#    'E226': 2,
#    'E117': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['10',
#   'BAD',
#   'BAD',
#   {'C0303': 21,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '30 (-)',
#    'C0116': 10,
#    'W0613': 4,
#    'R1710': 2,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0200': 2},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 4,
#    'SC200': 37,
#    'WPS331': 3,
#    'R504': 2,
#    'R1710': 2,
#    'R503': 2,
#    'E231': 16,
#    'E228': 2,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'WPS507': 1,
#    'R1703': 1,
#    'WPS503': 1,
#    'WPS440': 2,
#    'C0200': 2,
#    'WPS432': 2,
#    'E262': 3}],
#  ['11',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 13,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '5 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 81,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 2,
#    'WPS529': 2,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 3,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS204': 1,
#    'WPS528': 1,
#    'E262': 1}],
#  ['12',
#   'BAD',
#   'BAD',
#   {'C0303': 27,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '20 (-)',
#    'C0116': 10,
#    'W0613': 5,
#    'C0200': 2,
#    'W0603': 2,
#    'W0702': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 5,
#    'SC200': 21,
#    'WPS331': 3,
#    'R504': 3,
#    'C0200': 2,
#    'E228': 2,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'W0702': 1,
#    'E722': 1,
#    'WPS440': 2,
#    'E225': 1,
#    'E231': 10,
#    'R1710': 1,
#    'R503': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['13',
#   'BAD',
#   'BAD',
#   {'C0303': 31,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0325': '2 ( Hyperstyle: C0325: 2 )',
#    'W0311': '5 ( Hyperstyle: E111: 3 W0311: 2 )',
#    'W0105': 6,
#    'C0103': '27 (-)',
#    'C0116': 10,
#    'W0613': 3,
#    'W0603': 2,
#    'C0200': 1,
#    'R1705': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 3,
#    'SC200': 18,
#    'WPS331': 3,
#    'R504': 3,
#    'E225': 4,
#    'WPS519': 1,
#    'E261': 15,
#    'SC100': 2,
#    'E265': 2,
#    'E115': 1,
#    'WPS440': 2,
#    'E262': 4,
#    'E231': 10,
#    'R1710': 1,
#    'C0200': 1,
#    'R503': 1,
#    'E117': 1,
#    'WPS432': 2}],
#  ['14',
#   'BAD',
#   'BAD',
#   {'C0303': 27,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'W0311': '7 ( Hyperstyle: W0311: 4 )',
#    'W0105': 6,
#    'C0103': '20 (-)',
#    'C0116': 10,
#    'W0613': 6,
#    'W0612': '1 (-)',
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0200': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 6,
#    'SC200': 14,
#    'E225': 12,
#    'WPS331': 3,
#    'R504': 3,
#    'W0612': 1,
#    'E226': 2,
#    'E228': 2,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'E231': 11,
#    'WPS529': 1,
#    'WPS440': 2,
#    'E117': 2,
#    'R1703': 1,
#    'WPS503': 1,
#    'R1710': 1,
#    'C0200': 1,
#    'R503': 1,
#    'E211': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['15',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 17,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0103': '4 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 85,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 2,
#    'WPS529': 2,
#    'R1703': 1,
#    'WPS503': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 2,
#    'E251': 18,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS528': 2,
#    'E262': 1}],
#  ['16',
#   'BAD',
#   'BAD',
#   {'C0303': 24,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0325': '1 ( Hyperstyle: WPS313: 1 )',
#    'W0105': 6,
#    'C0103': '24 (-)',
#    'C0116': 10,
#    'W0613': 4,
#    'W0612': '1 ( Hyperstyle: B007: 1 )',
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 4,
#    'SC200': 14,
#    'WPS519': 2,
#    'E228': 2,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'R503': 2,
#    'E225': 3,
#    'WPS529': 1,
#    'WPS440': 2,
#    'WPS504': 1,
#    'WPS531': 1,
#    'WPS520': 1,
#    'WPS503': 1,
#    'E231': 11,
#    'R1710': 1,
#    'E226': 2,
#    'WPS432': 2,
#    'E262': 3}],
#  ['17',
#   'BAD',
#   'BAD',
#   {'C0303': 11,
#    'C0301': '16 ( Hyperstyle: E501: 12 )',
#    'W0105': 6,
#    'C0103': '21 (-)',
#    'C0116': 10,
#    'W0613': 4,
#    'W0603': 4,
#    'R1703': 1,
#    'R1705': 1,
#    'W0120': 1,
#    'W0622': '1 ( Hyperstyle: A001: 1 )',
#    'C0200': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 4,
#    'SC200': 16,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'R1703': 1,
#    'WPS503': 2,
#    'WPS440': 2,
#    'WPS500': 1,
#    'W0120': 1,
#    'E231': 9,
#    'R1710': 1,
#    'C0200': 1,
#    'R503': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['18',
#   'BAD',
#   'BAD',
#   {'C0303': 26,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'W0311': '33 ( Hyperstyle: E111: 14 W0311: 19 )',
#    'W0105': 6,
#    'C0103': '23 (-)',
#    'C0116': 10,
#    'W0613': 5,
#    'W0621': 3,
#    'W0612': '1 (-)',
#    'C0115': 1,
#    'W0601': 5,
#    'R0201': 4,
#    'E0601': '1 (-)',
#    'R1703': 1,
#    'R1705': 1,
#    'C0200': 1,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 5,
#    'SC200': 26,
#    'W0621': 3,
#    'W0612': 1,
#    'WPS519': 1,
#    'E228': 2,
#    'E261': 14,
#    'H601': 1,
#    'E231': 16,
#    'R0201': 4,
#    'W0601': 5,
#    'SC100': 3,
#    'E114': 14,
#    'E265': 3,
#    'E0601': 1,
#    'E271': 1,
#    'E225': 7,
#    'E226': 2,
#    'WPS464': 1,
#    'R1703': 1,
#    'WPS503': 1,
#    'WPS529': 1,
#    'WPS440': 2,
#    'C0200': 1,
#    'R504': 1,
#    'R1710': 1,
#    'R503': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['19',
#   'BAD',
#   'BAD',
#   {'C0303': 14,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'W0311': '2 ( Hyperstyle: E111: 1 W0311: 1 )',
#    'W0105': 6,
#    'C0103': '15 (-)',
#    'C0116': 10,
#    'W0613': 4,
#    'W0603': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0200': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 4,
#    'SC200': 23,
#    'E225': 1,
#    'E228': 1,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'WPS507': 1,
#    'E117': 1,
#    'R1703': 1,
#    'WPS503': 1,
#    'WPS529': 2,
#    'WPS440': 2,
#    'WPS508': 1,
#    'E231': 24,
#    'C0200': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['20',
#   'BAD',
#   'BAD',
#   {'C0303': 15,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '29 (-)',
#    'C0116': 10,
#    'W0613': 3,
#    'W0603': 2,
#    'R1705': 1,
#    'C0200': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 3,
#    'SC200': 19,
#    'WPS529': 2,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'WPS507': 1,
#    'WPS531': 1,
#    'WPS440': 2,
#    'E231': 11,
#    'C0200': 1,
#    'E226': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['21',
#   'BAD',
#   'BAD',
#   {'C0303': 15,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '21 (-)',
#    'C0116': 10,
#    'W0613': 6,
#    'R1710': 1,
#    'W0603': 1,
#    'W0612': '1 (-)',
#    'C0413': 1,
#    'W0621': 1,
#    'R1705': 1,
#    'E1111': 3,
#    'W0611': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 6,
#    'SC200': 13,
#    'E225': 13,
#    'WPS331': 5,
#    'R504': 2,
#    'R1710': 1,
#    'R503': 2,
#    'WPS528': 2,
#    'E228': 1,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'WPS428': 4,
#    'W0612': 1,
#    'WPS440': 2,
#    'W0611': 1,
#    'W0621': 1,
#    'WPS503': 1,
#    'E231': 9,
#    'E1111': 3,
#    'WPS432': 2,
#    'E262': 3}],
#  ['22',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 17,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '5 (-)',
#    'R1703': 1,
#    'R1705': 1,
#    'W0404': 1,
#    'W0612': '1 (-)'},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 93,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 2,
#    'WPS529': 2,
#    'E231': 10,
#    'WPS507': 1,
#    'R1703': 1,
#    'WPS503': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 2,
#    'E251': 18,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C002': 1,
#    'W0612': 1,
#    'E262': 1}],
#  ['23',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 18,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1724': 1,
#    'C0103': '4 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 14,
#    'SC200': 86,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 4,
#    'R503': 2,
#    'WPS529': 2,
#    'WPS507': 1,
#    'E262': 9,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 2,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS528': 1}],
#  ['24',
#   'BAD',
#   'BAD',
#   {'C0303': 21,
#    'C0301': '9 ( Hyperstyle: E501: 7 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '11 (-)',
#    'C0116': 4,
#    'R1710': 1,
#    'R1723': 1,
#    'W0612': '2 ( Hyperstyle: B007: 1 )',
#    'R1702': 1,
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'WPS428': 4,
#    'R503': 1,
#    'E226': 10,
#    'E261': 43,
#    'E262': 30,
#    'SC200': 22,
#    'C812': 5,
#    'F401': 1,
#    'WPS231': 2,
#    'E265': 1,
#    'E225': 2,
#    'WPS504': 1,
#    'WPS507': 1,
#    'F841': 1,
#    'WPS204': 3,
#    'WPS220': 5,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['25',
#   'BAD',
#   'BAD',
#   {'C0303': 19,
#    'C0301': '6 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '12 ( Hyperstyle: E741: 1 )',
#    'C0116': 4,
#    'R1710': 1,
#    'C0200': 1,
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'R1710': 1,
#    'R503': 1,
#    'E226': 2,
#    'WPS519': 2,
#    'E231': 18,
#    'SC200': 19,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'WPS231': 1,
#    'C0200': 1,
#    'WPS440': 2,
#    'E225': 1,
#    'W0621': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['26',
#   'BAD',
#   'BAD',
#   {'C0301': '6 ( Hyperstyle: E501: 3 )',
#    'C0303': 13,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '4 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 39,
#    'SC200': 87,
#    'SC100': 19,
#    'R1710': 2,
#    'E265': 4,
#    'R503': 2,
#    'WPS529': 2,
#    'E262': 34,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 2,
#    'E251': 18,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'C901': 1,
#    'WPS231': 1,
#    'WPS528': 2}],
#  ['27',
#   'BAD',
#   'BAD',
#   {'C0303': 12,
#    'C0301': '14 ( Hyperstyle: E501: 14 )',
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '20 (-)',
#    'C0116': 10,
#    'W0613': 11,
#    'W0622': '1 ( Hyperstyle: A001: 1 )',
#    'W0612': '2 (-)',
#    'W0603': 1,
#    'R1705': 1,
#    'E1111': 3},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 11,
#    'SC200': 13,
#    'E211': 1,
#    'W0612': 2,
#    'WPS428': 5,
#    'E261': 14,
#    'SC100': 2,
#    'E265': 2,
#    'WPS440': 2,
#    'WPS531': 1,
#    'WPS503': 1,
#    'E231': 9,
#    'E1111': 3,
#    'WPS432': 2,
#    'E262': 3}],
#  ['28',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 18,
#    'C0325': '2 ( Hyperstyle: C0325: 2 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'W0622': '1 ( Hyperstyle: A001: 1 )',
#    'C0103': '4 (-)',
#    'C0121': 1,
#    'W0101': 1,
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 84,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 3,
#    'WPS529': 2,
#    'WPS428': 2,
#    'E225': 13,
#    'WPS507': 1,
#    'E231': 25,
#    'C0121': 1,
#    'E712': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 2,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS528': 2,
#    'E211': 1,
#    'E226': 2,
#    'E262': 1}],
#  ['29',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 21,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '6 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 83,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 2,
#    'WPS529': 2,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 3,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'E241': 8,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS204': 1,
#    'WPS528': 1,
#    'E262': 1}],
#  ['30',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 33,
#    'W0311': '2 ( Hyperstyle: W0311: 1 )',
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1705': 1,
#    'C0103': '6 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 6,
#    'SC200': 84,
#    'E262': 2,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 4,
#    'R503': 2,
#    'WPS529': 2,
#    'E231': 38,
#    'WPS507': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 4,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS204': 1,
#    'B007': 1,
#    'WPS528': 1,
#    'E117': 1,
#    'E225': 2,
#    'WPS220': 2}],
#  ['31',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 17,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '5 (-)',
#    'R1705': 1,
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 85,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 2,
#    'WPS529': 2,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 2,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'C901': 1,
#    'WPS231': 1,
#    'WPS528': 1,
#    'E262': 1}],
#  ['32',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 19,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '5 (-)',
#    'R1705': 1,
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 86,
#    'E231': 43,
#    'SC100': 13,
#    'R1710': 2,
#    'E265': 5,
#    'R503': 2,
#    'WPS529': 2,
#    'WPS507': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 2,
#    'E251': 18,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS528': 2,
#    'E262': 1}],
#  ['33',
#   'BAD',
#   'BAD',
#   {'E0001': '1 ( Hyperstyle: E0001: 1 )'},
#   {'E261': 5,
#    'E265': 3,
#    'E114': 2,
#    'E116': 2,
#    'E501': 1,
#    'E251': 2,
#    'E713': 2,
#    'E112': 1,
#    'E999': 1,
#    'E262': 1}],
#  ['34',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 17,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'W0101': 2,
#    'W0612': '3 (-)',
#    'C0103': '4 (-)',
#    'W0404': 1,
#    'E1121': 8},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 82,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 3,
#    'WPS529': 2,
#    'WPS428': 3,
#    'W0612': 3,
#    'W0101': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 2,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'E1121': 8,
#    'E262': 1}],
#  ['35',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 13,
#    'W0311': '3 ( Hyperstyle: E111: 1 W0311: 2 )',
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'R1703': 1,
#    'R1705': 1,
#    'C0103': '5 (-)',
#    'W0404': 1,
#    'W0612': '1 (-)'},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 85,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 2,
#    'WPS529': 2,
#    'E201': 2,
#    'E231': 12,
#    'WPS231': 2,
#    'E225': 3,
#    'WPS444': 1,
#    'WPS507': 1,
#    'E701': 1,
#    'R1703': 1,
#    'E117': 1,
#    'WPS503': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 3,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'C901': 1,
#    'C002': 1,
#    'WPS204': 1,
#    'WPS528': 1,
#    'W0612': 1,
#    'WPS220': 2,
#    'E262': 1}],
#  ['36',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 14,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '5 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 88,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 3,
#    'R503': 2,
#    'WPS529': 2,
#    'WPS231': 2,
#    'WPS440': 5,
#    'R504': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'E231': 8,
#    'WPS432': 5,
#    'C901': 1,
#    'C002': 1,
#    'WPS204': 1,
#    'WPS528': 2,
#    'E225': 5,
#    'E226': 2,
#    'E262': 1}],
#  ['37',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 22,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '5 (-)',
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 84,
#    'SC100': 12,
#    'R1710': 2,
#    'E265': 4,
#    'R503': 2,
#    'WPS529': 2,
#    'WPS507': 1,
#    'E231': 9,
#    'E114': 3,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 3,
#    'E251': 2,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS204': 1,
#    'WPS528': 2,
#    'E262': 1}],
#  ['38',
#   'BAD',
#   'BAD',
#   {'E0001': '1 ( Hyperstyle: E0001: 1 )'},
#   {'E261': 5,
#    'E265': 3,
#    'E114': 2,
#    'E116': 2,
#    'E501': 1,
#    'E251': 2,
#    'E713': 2,
#    'E112': 1,
#    'E999': 1,
#    'E262': 1}],
#  ['39',
#   'BAD',
#   'BAD',
#   {'C0301': '2 ( Hyperstyle: E501: 1 )',
#    'C0303': 30,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0116': 11,
#    'R1710': 2,
#    'C0103': '7 (-)',
#    'R1705': 1,
#    'W0404': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'E261': 5,
#    'SC200': 84,
#    'SC100': 11,
#    'R1710': 2,
#    'E265': 4,
#    'R503': 2,
#    'WPS529': 2,
#    'E231': 23,
#    'WPS507': 1,
#    'E225': 1,
#    'E114': 2,
#    'E116': 2,
#    'W0404': 1,
#    'WPS440': 2,
#    'E251': 18,
#    'E713': 2,
#    'WPS508': 2,
#    'WPS432': 5,
#    'WPS231': 1,
#    'C901': 1,
#    'C002': 1,
#    'WPS528': 2,
#    'E262': 1}],
#  ['40',
#   'BAD',
#   'BAD',
#   {'E0001': '1 ( Hyperstyle: E0001: 1 )'},
#   {'E261': 5,
#    'E265': 3,
#    'E231': 1,
#    'E114': 2,
#    'E116': 2,
#    'E501': 1,
#    'E251': 2,
#    'E713': 2,
#    'E112': 1,
#    'E999': 1,
#    'E262': 1}],
#  ['41',
#   'BAD',
#   'BAD',
#   {'C0303': 21,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 3,
#    'C0103': '13 (-)',
#    'C0116': 4,
#    'W0101': 1,
#    'W0612': '2 (-)',
#    'C0200': 1,
#    'W0621': 1,
#    'W0611': 2},
#   {'WPS462': 4,
#    'W0105': 4,
#    'W0611': 2,
#    'WPS458': 1,
#    'WPS231': 2,
#    'E231': 17,
#    'E226': 11,
#    'WPS220': 1,
#    'R504': 1,
#    'SC200': 24,
#    'E261': 12,
#    'C812': 5,
#    'W0612': 2,
#    'E265': 2,
#    'W0101': 1,
#    'E225': 1,
#    'C0200': 1,
#    'W0621': 1,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['42',
#   'BAD',
#   'BAD',
#   {'C0303': 13,
#    'C0301': '13 ( Hyperstyle: E501: 14 )',
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'C0304': 1,
#    'W0105': 6,
#    'C0103': '21 (-)',
#    'C0116': 10,
#    'W0613': 5,
#    'W0622': '4 ( Hyperstyle: A001: 6 )',
#    'W0621': 1,
#    'W0603': 3,
#    'W0612': '1 (-)',
#    'R1703': 1,
#    'R1705': 3,
#    'R1710': 1},
#   {'WPS462': 6,
#    'W0105': 6,
#    'W0613': 5,
#    'SC200': 21,
#    'WPS331': 4,
#    'R504': 4,
#    'WPS519': 1,
#    'E228': 2,
#    'E261': 17,
#    'W0621': 1,
#    'W0612': 1,
#    'SC100': 2,
#    'E265': 2,
#    'WPS507': 1,
#    'R1703': 1,
#    'WPS503': 1,
#    'WPS529': 4,
#    'WPS440': 2,
#    'E231': 9,
#    'R1710': 1,
#    'R503': 1,
#    'WPS432': 2,
#    'E262': 3}],
#  ['43',
#   'BAD',
#   'BAD',
#   {'C0303': 33,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0311': '1 ( Hyperstyle: E111: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '9 (-)',
#    'C0116': 4,
#    'W0621': 2,
#    'R1710': 1,
#    'W0612': '1 (-)',
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'R1710': 1,
#    'WPS231': 2,
#    'R503': 1,
#    'E231': 3,
#    'SC200': 27,
#    'W0621': 2,
#    'WPS440': 2,
#    'WPS504': 1,
#    'E225': 8,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'W0612': 1,
#    'E272': 1,
#    'E271': 1,
#    'E226': 6,
#    'E221': 1,
#    'E117': 1,
#    'E203': 1,
#    'E222': 1,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['44',
#   'BAD',
#   'BAD',
#   {'C0303': 19,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '13 (-)',
#    'C0116': 4,
#    'W0613': 1,
#    'E1111': 4,
#    'W0612': '3 (-)',
#    'W0621': 1,
#    'W0611': 2},
#   {'WPS462': 4,
#    'W0105': 4,
#    'W0611': 2,
#    'W0613': 1,
#    'WPS428': 2,
#    'SC200': 19,
#    'E261': 12,
#    'C812': 5,
#    'E1111': 4,
#    'W0612': 3,
#    'WPS231': 1,
#    'E225': 10,
#    'E226': 7,
#    'E211': 2,
#    'WPS204': 3,
#    'E231': 2,
#    'WPS441': 1,
#    'W0621': 1,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['45',
#   'BAD',
#   'BAD',
#   {'C0303': 17,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '9 (-)',
#    'C0116': 4,
#    'R1710': 1,
#    'W0612': '2 (-)',
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'R1710': 1,
#    'W0612': 2,
#    'R503': 1,
#    'E231': 5,
#    'E226': 8,
#    'SC200': 22,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'WPS432': 1,
#    'E225': 3,
#    'W0621': 1,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['46',
#   'BAD',
#   'BAD',
#   {'C0303': 20,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '11 (-)',
#    'C0116': 4,
#    'R1710': 1,
#    'W0621': 2,
#    'W0612': '1 (-)',
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'R1710': 1,
#    'E231': 1,
#    'WPS432': 2,
#    'R503': 1,
#    'WPS519': 2,
#    'SC200': 19,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'W0621': 2,
#    'E222': 1,
#    'E225': 1,
#    'E226': 7,
#    'W0612': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['47',
#   'BAD',
#   'BAD',
#   {'E0001': '1 ( Hyperstyle: E0001: 1 )'},
#   {'E501': 5,
#    'E231': 4,
#    'E226': 5,
#    'E741': 1,
#    'E261': 12,
#    'E225': 1,
#    'E112': 1,
#    'E999': 1,
#    'W391': 1}],
#  ['48',
#   'BAD',
#   'BAD',
#   {'C0303': 21,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0301': 1,
#    'C0325': '1 ( Hyperstyle: C0325: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '12 ( Hyperstyle: E741: 1 )',
#    'C0116': 4,
#    'C0200': 1,
#    'W0612': '5 (-)',
#    'E1111': 2,
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'WPS231': 1,
#    'W0612': 5,
#    'E231': 11,
#    'E703': 1,
#    'C0200': 1,
#    'E265': 6,
#    'E225': 3,
#    'E203': 2,
#    'R504': 2,
#    'SC200': 19,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'WPS428': 2,
#    'E1111': 2,
#    'E226': 1,
#    'W0621': 1,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['49',
#   'BAD',
#   'BAD',
#   {'C0303': 16,
#    'C0301': '6 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '12 (-)',
#    'C0116': 4,
#    'R1721': 2,
#    'R1710': 1,
#    'C0200': 3,
#    'R0914': 1,
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'R1710': 1,
#    'R1721': 2,
#    'R503': 1,
#    'E226': 12,
#    'SC200': 19,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'C901': 2,
#    'WPS231': 2,
#    'WPS204': 3,
#    'C0200': 3,
#    'WPS441': 8,
#    'WPS440': 2,
#    'C414': 1,
#    'C002': 1,
#    'E225': 1,
#    'WPS519': 2,
#    'WPS220': 6,
#    'WPS507': 1,
#    'W0621': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['50',
#   'BAD',
#   'BAD',
#   {'C0303': 20,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '9 (-)',
#    'C0116': 4,
#    'C0200': 2,
#    'W0612': '1 (-)',
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'SC200': 25,
#    'E231': 3,
#    'E226': 7,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'WPS231': 1,
#    'C0200': 2,
#    'WPS440': 2,
#    'E225': 1,
#    'W0612': 1,
#    'W0621': 1,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['51',
#   'BAD',
#   'BAD',
#   {'C0303': 17,
#    'C0301': '10 ( Hyperstyle: E501: 7 )',
#    'W0105': 4,
#    'C0413': 1,
#    'C0116': 4,
#    'R1710': 1,
#    'C0103': '8 (-)',
#    'W0621': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'R1710': 1,
#    'R503': 1,
#    'E261': 35,
#    'E262': 23,
#    'WPS519': 2,
#    'C405': 1,
#    'SC200': 19,
#    'C812': 5,
#    'WPS440': 2,
#    'SC100': 4,
#    'WPS441': 3,
#    'E225': 1,
#    'E226': 1,
#    'W0621': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['52',
#   'BAD',
#   'BAD',
#   {'C0303': 18,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 3,
#    'C0103': '12 (-)',
#    'C0116': 4,
#    'R1710': 1,
#    'W0404': 1,
#    'W0612': '2 (-)',
#    'W0621': 1,
#    'E1111': 2,
#    'W0611': 1,
#    'C0412': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'R1710': 1,
#    'R503': 1,
#    'E231': 11,
#    'N806': 1,
#    'SC200': 24,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'C0412': 1,
#    'W0404': 1,
#    'WPS440': 1,
#    'WPS231': 1,
#    'E226': 2,
#    'W0612': 2,
#    'E225': 1,
#    'WPS428': 1,
#    'W0621': 1,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1,
#    'E1111': 2}],
#  ['53',
#   'BAD',
#   'BAD',
#   {'C0303': 21,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'C0325': '2 ( Hyperstyle: WPS313: 1 C0325: 1 )',
#    'C0304': 1,
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '16 (-)',
#    'C0116': 4,
#    'R1710': 1,
#    'W0612': '3 (-)',
#    'E1111': 2,
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'R1710': 1,
#    'WPS231': 2,
#    'E265': 1,
#    'R503': 1,
#    'E231': 4,
#    'E226': 6,
#    'SC200': 19,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'W0612': 3,
#    'E1111': 2,
#    'E225': 3,
#    'WPS204': 3,
#    'W0621': 1,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['54',
#   'BAD',
#   'BAD',
#   {'E0001': '1 ( Hyperstyle: E0001: 1 )'},
#   {'E902': 1, 'E501': 5}],
#  ['55',
#   'BAD',
#   'BAD',
#   {'C0303': 25,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0311': '1 ( Hyperstyle: E111: 1 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '15 (-)',
#    'C0116': 4,
#    'R1710': 1,
#    'W0612': '4 (-)',
#    'E1111': 2,
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'R1710': 1,
#    'E117': 1,
#    'R503': 1,
#    'SC200': 21,
#    'E231': 10,
#    'E225': 6,
#    'WPS519': 2,
#    'C405': 1,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'W0612': 4,
#    'E1111': 2,
#    'E226': 2,
#    'E211': 1,
#    'E203': 1,
#    'W0621': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['56',
#   'BAD',
#   'BAD',
#   {'C0303': 20,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '10 ( Hyperstyle: E741: 1 )',
#    'C0116': 4,
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'WPS231': 2,
#    'WPS507': 1,
#    'SC200': 18,
#    'E261': 12,
#    'C812': 5,
#    'W0611': 1,
#    'WPS440': 1,
#    'E225': 1,
#    'E226': 6,
#    'W0621': 1,
#    'WPS519': 1,
#    'WPS237': 1,
#    'WPS336': 1}],
#  ['57',
#   'BAD',
#   'BAD',
#   {'C0303': 12,
#    'C0301': '5 ( Hyperstyle: E501: 5 )',
#    'W0105': 4,
#    'C0413': 2,
#    'C0103': '11 (-)',
#    'C0116': 4,
#    'W0612': '2 (-)',
#    'W0621': 1,
#    'W0611': 1},
#   {'WPS462': 4,
#    'W0105': 4,
#    'WPS231': 2,
#    'R503': 1,
#    'WPS519': 3,
#    'WPS503': 2,
#    'WPS432': 2,
#    'SC200': 19,
#    'C812': 5,
#    'W0611': 1,
#    'C901': 1,
#    'W0612': 2,
#    'W0621': 1,
#    'WPS237': 1,
#    'WPS336': 1}]]

# %%
# Collect Pylint Error Code in common with hyperstyle
pylintCode = []
hyperCode = []
for singleCode in errorCode:
    if singleCode[0] in allErrorCodes:
        pylintCode.append(singleCode)
    else: # Collect Hyperstyle Error Code
        hyperCode.append(singleCode)
        
# Sort error codes
pylintCode.sort(key = lambda x:x[0])

# Sort error codes
hyperCode.sort(key = lambda x:x[0])
               
# print(pylintCode)
# print(hyperCode)

# %%
# ==================== EXCEL ====================

# %%
# import package
import xlsxwriter 
from openpyxl import Workbook
from openpyxl.styles import Alignment
from openpyxl.styles import PatternFill
from openpyxl.styles import Font

# Create Workbook 
workbook = Workbook()

# Delete the empty worksheet
del workbook["Sheet"]

# Sheets Names
sName1 = "Comparision of Tools' Outcomes"

# Create Sheet
workbook.create_sheet(sName1)

# Choose worksheet
sheet = workbook[sName1]

# %%
# Create worksheet x-axis title
sheet["A1"] = "Student ID"
sheet.column_dimensions['A'].width = 30
sheet["A1"].alignment = Alignment(horizontal = 'center')
sheet["B1"] = "Code Quality"
sheet.column_dimensions['B'].width = 30
sheet["B1"].alignment = Alignment(horizontal = 'center')
sheet["C1"] = "Text Quality"
sheet.column_dimensions['C'].width = 30
sheet["C1"].alignment = Alignment(horizontal = 'center')

index = 0
for row in sheet.iter_rows(min_row = 1, min_col = 4, max_row = 1, max_col = len(simpleCodeReference) + 3):
    for cell in row:
        sheet.column_dimensions[xlsxwriter.utility.xl_col_to_name(cell.column - 1)].width = 40
        cell.value = simpleCodeReference[index][0]
        cell.alignment = Alignment(horizontal = 'center')
        cell.fill = PatternFill(start_color = "00FFFF00", end_color = "00FFFF00", fill_type = "solid")
        cell.font = Font(bold = True)
        index += 1
        
index = 0
for row in sheet.iter_rows(min_row = 1, min_col = len(simpleCodeReference) + 7, max_row = 1, max_col = len(simpleCodeReference) + len(simpleCodeReferenceHyper) + 6):
    for cell in row:
        sheet.column_dimensions[xlsxwriter.utility.xl_col_to_name(cell.column - 1)].width = 40
        cell.value = simpleCodeReferenceHyper[index][0]
        cell.alignment = Alignment(horizontal = 'center')
        cell.fill = PatternFill(start_color = "00FFFF00", end_color = "00FFFF00", fill_type = "solid")
        cell.font = Font(bold = True)
        index += 1

# %%
# Fill in the information of each student (Pylint)

# Define the level of numbers of errors (for visualizarion later)
maxError = 0
for processedStudent in processedStudents:
    if maxError < max(processedStudent[1].values()):
        maxError = max(processedStudent[1].values())

studentIndex = 0
for row in sheet.iter_rows(min_row = 2, min_col = 1, max_row = len(processedStudents) + 1, max_col = len(simpleCodeReference) + 3):
    flag = True
    errorCodeIndex = 0
    for cell in row:
        if flag:
            cell.value = processedStudents[studentIndex][0]
            cell.font = Font(bold = True)
            flag = False
        elif cell.column == 2:
            cell.value = mergedInfo[studentIndex][1]
            cell.font = Font(bold = True)
            if cell.value == "BAD":
                cell.fill = PatternFill(start_color = 'FF0000', end_color = 'FF0000', fill_type = "solid")
            elif cell.value == "MODERATE":
                cell.fill = PatternFill(start_color = 'FFFF00', end_color = 'FFFF00', fill_type = "solid")
            else:
                cell.fill = PatternFill(start_color = '00FF00', end_color = '00FF00', fill_type = "solid")
        elif cell.column == 3:
            cell.value = mergedInfo[studentIndex][2]
            cell.font = Font(bold = True)
        else:
            # Loop through set of error codes
            errorCodes = mergedInfo[studentIndex][3]
            if allErrorCodes[errorCodeIndex] in errorCodes:
                cell.value = errorCodes[allErrorCodes[errorCodeIndex]]
                # Add gradient colors for better visualization
                if type(cell.value) == str:
                    colorGradient = int(str(cell.value)[ : str(cell.value).find(" ")])
                else:
                    colorGradient = cell.value
                hexColor = '#%02x%02x%02x' % ((int)(255 - ((colorGradient / maxError) * 255)), (int)(255 - ((colorGradient / maxError) * 155)), 255)
                cell.fill = PatternFill(start_color = str(hexColor)[1:], end_color = str(hexColor)[1:], fill_type = "solid")
            errorCodeIndex += 1  
        cell.alignment = Alignment(horizontal = 'center')
    studentIndex += 1
    
    
# Count warning message occurrence

# Title of the row
sheet.cell(row = len(processedStudents) + 2, column = 1).value = "Warning Message Occurrence"
sheet.cell(row = len(processedStudents) + 2, column = 1).font = Font(bold = True)
sheet.cell(row = len(processedStudents) + 2, column = 1).alignment = Alignment(horizontal = 'center')

# Fill the frequency of each warning message
errorFreq = []
for singleError in allErrorCodes:
    errorCounter = 0
    for processedStudent in processedStudents:
        if singleError in processedStudent[1]:
            errorCounter += processedStudent[1][singleError]
    errorFreq.append(errorCounter)

maxError = max(errorFreq)
errorIndex = 0
for row in sheet.iter_rows(min_row = len(processedStudents) + 2, min_col = 4, max_row = len(processedStudents) + 2, max_col = len(allErrorCodes) + 3):
    for cell in row:
        cell.value = errorFreq[errorIndex]
        cell.alignment = Alignment(horizontal = 'center')
         # Add gradient colors for better visualization
        hexColor = '#%02x%02x%02x' % (255, (int)(255 - ((cell.value / maxError) * 255)), (int)(255 - ((cell.value / maxError) * 255)))
        cell.fill = PatternFill(start_color = str(hexColor)[1:], end_color = str(hexColor)[1:], fill_type = "solid")
        errorIndex += 1
   

# Add code reference to excel
# Title of the row
sheet.cell(row = len(processedStudents) + 3, column = 1).value = "Code Reference"
sheet.cell(row = len(processedStudents) + 3, column = 1).font = Font(bold = True)
sheet.cell(row = len(processedStudents) + 3, column = 1).alignment = Alignment(horizontal = 'center')
refIndex = 0
for row in sheet.iter_rows(min_row = len(processedStudents) + 3, min_col = 4, max_row = len(processedStudents) + 3, max_col = len(allErrorCodes) + 3):
    for cell in row:
        cell.value = simpleCodeReference[refIndex][1]
        cell.alignment = Alignment(horizontal = 'center')
        refIndex += 1

# %%
# Fill in the information of each student (Hyperstyle)

# Define the level of numbers of errors (for visualizarion later)
maxError = 0
for processedStudent in mergedInfo:
    if maxError < max(processedStudent[4].values()):
        maxError = max(processedStudent[4].values())
        
studentIndex = 0
for row in sheet.iter_rows(min_row = 2, min_col = len(simpleCodeReference) + 7, max_row = len(processedStudents) + 1, max_col = len(simpleCodeReference) + len(simpleCodeReferenceHyper) + 6):
    errorCodeIndex = 0
    for cell in row:
        # Loop through set of error codes
        errorCodes = mergedInfo[studentIndex][4] # map
        if simpleCodeReferenceHyper[errorCodeIndex][0] in errorCodes:
            cell.value = errorCodes[simpleCodeReferenceHyper[errorCodeIndex][0]]
            # Add gradient colors for better visualization
            hexColor = '#%02x%02x%02x' % ((int)(255 - ((cell.value / maxError) * 255)), (int)(255 - ((cell.value / maxError) * 155)), 255)
            cell.fill = PatternFill(start_color = str(hexColor)[1:], end_color = str(hexColor)[1:], fill_type = "solid")
        errorCodeIndex += 1  
        cell.alignment = Alignment(horizontal = 'center')
    studentIndex += 1
    
    
# Fill the frequency of each warning message
errorFreq = []
for singleError in simpleCodeReferenceHyper:
    errorCounter = 0
    for processedStudent in mergedInfo:
        if singleError[0] in processedStudent[4]:
            errorCounter += processedStudent[4][singleError[0]]
    errorFreq.append(errorCounter)

maxError = max(errorFreq)
errorIndex = 0
for row in sheet.iter_rows(min_row = len(processedStudents) + 2, min_col = len(simpleCodeReference) + 7, max_row = len(processedStudents) + 2, max_col = len(simpleCodeReference) + len(simpleCodeReferenceHyper) + 6):
    for cell in row:
        cell.value = errorFreq[errorIndex]
        cell.alignment = Alignment(horizontal = 'center')
         # Add gradient colors for better visualization
        hexColor = '#%02x%02x%02x' % (255, (int)(255 - ((cell.value / maxError) * 255)), (int)(255 - ((cell.value / maxError) * 255)))
        cell.fill = PatternFill(start_color = str(hexColor)[1:], end_color = str(hexColor)[1:], fill_type = "solid")
        errorIndex += 1
        
        
# Add code reference to excel
refIndex = 0
for row in sheet.iter_rows(min_row = len(processedStudents) + 3, min_col = len(simpleCodeReference) + 7, max_row = len(processedStudents) + 3, max_col = len(simpleCodeReference) + len(simpleCodeReferenceHyper) + 6):
    for cell in row:
        cell.value = simpleCodeReferenceHyper[refIndex][1]
        cell.alignment = Alignment(horizontal = 'center')
        refIndex += 1

# %%
# Add some comments
sheet.cell(row = len(processedStudents) + 5, column = 4).value = "Dash (-) means Hyperstyle does not detect the same error if we can find the mapping rule."

# %%
#======================== Task 2 ===============================
def insertCodes(sheet, col, arrIndex, makeBold, arr):
    index = 0
    for row in sheet.iter_rows(min_row = 2, min_col = col, max_row = len(arr)+1, max_col = col):
        for cell in row:
            cell.value = arr[index][arrIndex]
            cell.alignment = Alignment(horizontal = 'center')
            if (makeBold == True): 
                cell.font = Font(bold = True)
            index += 1
            
# Sheets Names
sName = "Pylint Error Codes"

# Create Sheet
workbook.create_sheet(sName)

# Choose worksheet
sheet = workbook[sName]

sheet["A1"] = "Pylint Error Codes"
sheet.column_dimensions['A'].width = 15
sheet["A1"].alignment = Alignment(horizontal = 'center')

sheet["B1"] = "Stegman's Category"
sheet.column_dimensions['B'].width = 25
sheet["B1"].alignment = Alignment(horizontal = 'center')

sheet["C1"] = "Hyperstyle's Catagory"
sheet.column_dimensions['C'].width = 25
sheet["C1"].alignment = Alignment(horizontal = 'center')

sheet["D1"] = "Hyperstyle's Difficulty"
sheet.column_dimensions['D'].width = 25
sheet["D1"].alignment = Alignment(horizontal = 'center')

sheet["E1"] = "Hyperstyle's Text"
sheet.column_dimensions['E'].width = 55
sheet["E1"].alignment = Alignment(horizontal = 'center')

insertCodes(sheet, 3, 2, False, pylintCode)
insertCodes(sheet, 4, 3, False, pylintCode)
insertCodes(sheet, 5, 1, False, pylintCode)
insertCodes(sheet, 1, 0, True, pylintCode)

# %%
#======================== Task 3 ===============================
# Sheets Names
sName2 = "Hyperstyle Error Codes"

# Create Sheet
workbook.create_sheet(sName2)

# Choose worksheet
sheet = workbook[sName2]


sheet["A1"] = "Hyperstyle Error Codes"
sheet.column_dimensions['A'].width = 15
sheet["A1"].alignment = Alignment(horizontal = 'center')

sheet["B1"] = "Stegman's Category"
sheet.column_dimensions['B'].width = 25
sheet["B1"].alignment = Alignment(horizontal = 'center')

sheet["C1"] = "Hyperstyle's Catagory"
sheet.column_dimensions['C'].width = 25
sheet["C1"].alignment = Alignment(horizontal = 'center')

sheet["D1"] = "Hyperstyle's Difficulty"
sheet.column_dimensions['D'].width = 25
sheet["D1"].alignment = Alignment(horizontal = 'center')

sheet["E1"] = "Hyperstyle's Text"
sheet.column_dimensions['E'].width = 100
sheet["E1"].alignment = Alignment(horizontal = 'center')

insertCodes(sheet, 3, 2, False, hyperCode)
insertCodes(sheet, 4, 3, False, hyperCode)
insertCodes(sheet, 5, 1, False, hyperCode)
insertCodes(sheet, 1, 0, True, hyperCode)

# %%
workbook.save(filename="Week3_Merged_Meaning_Dataset2.xlsx")
